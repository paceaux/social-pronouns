# %% [markdown]
# # Bruh Analysis
#
# This is a file for analyzing the use of "bronouns" from a SQL database

# %% [markdown]
# ## Setup

# %%
# dependencies
import sqlite3
import math
import re
import nltk
import pandas as pd
from datetime import datetime

# %%
# Initialize DB
connection = sqlite3.connect('../db.pronouns.with-data.sqlite')
cursor = connection.cursor()

# %%
# Get the Rows
# Make columns and pronoun variables, so this is reusable
sql_columns = ['indexedAt','uri', 'text']
column_titles = ['Time', 'URI', 'Post Text'] # This is for Pandas, later down
pronoun = 'bruh'
select_query = f"SELECT {','.join(sql_columns)} FROM post WHERE post.pronoun == '{pronoun}'"
cursor.execute(select_query)

pronoun_rows = cursor.fetchall()

# %% [markdown]
# ## Raw Data

# %%
# let's find out how many entries we have
size = len(pronoun_rows)

print(f"There are {size} instances of {pronoun}")
# Out:
# There are 3207 instances of bruh

# %%
# Let's look at a row
print(pronoun_rows[0])
# Out:
# ('2025-02-04T17:03:09.084Z', 'at://did:plc:qeld3yz6jsokau6vnwapubtz/app.bsky.feed.post/3lhejxvxv5c2q', 'Bruh im just tryna wallow in sadness why is that so hard nowadays')

# %%
# We want to see some. But let's not blow it up
max_table_rows = int(size * .3)
raw_slice_size = int(max_table_rows * .3)

pd.set_option('display.max_rows', max_table_rows )
pd.set_option('display.max_colwidth', None)

# %%
raw_frame = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)
raw_frame.style\
    .hide(axis="index")\
    .set_caption(f"Showing {raw_slice_size} of {size}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f244">
#   <caption>Showing 288 of 3207</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f244_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_1f244_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_1f244_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f244_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f244_row0_col0" class="data row0 col0" >2025-02-04T17:03:09.084Z</td>
#       <td id="T_1f244_row0_col1" class="data row0 col1" >at://did:plc:qeld3yz6jsokau6vnwapubtz/app.bsky.feed.post/3lhejxvxv5c2q</td>
#       <td id="T_1f244_row0_col2" class="data row0 col2" >Bruh im just tryna wallow in sadness why is that so hard nowadays</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f244_row1_col0" class="data row1 col0" >2025-02-04T17:05:03.107Z</td>
#       <td id="T_1f244_row1_col1" class="data row1 col1" >at://did:plc:bbeqyegnad5xy2nl6n5iw3zy/app.bsky.feed.post/3lhek3c2mtc26</td>
#       <td id="T_1f244_row1_col2" class="data row1 col2" >bruh finding somewhere to sit on my campus on my fav building is impossible im gonna die before i even get to one spot</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f244_row2_col0" class="data row2 col0" >2025-02-04T17:05:46.805Z</td>
#       <td id="T_1f244_row2_col1" class="data row2 col1" >at://did:plc:52bxkk7kixdpzgsile72ukcl/app.bsky.feed.post/3lhek4lkg3k2q</td>
#       <td id="T_1f244_row2_col2" class="data row2 col2" >Bruh they sold crack to black neighborhoods and played an active part in the 80s drug trade. They was never it to begin with!</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f244_row3_col0" class="data row3 col0" >2025-02-04T17:07:12.005Z</td>
#       <td id="T_1f244_row3_col1" class="data row3 col1" >at://did:plc:iixel3uapg43q4unbjx4a726/app.bsky.feed.post/3lhek754fmk25</td>
#       <td id="T_1f244_row3_col2" class="data row3 col2" >bruh if you don’t want to crawl inside of my skin then please leave me alone, I’m so tired of this nonchalant shit like do you fw me or not</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f244_row4_col0" class="data row4 col0" >2025-02-04T17:09:51.696Z</td>
#       <td id="T_1f244_row4_col1" class="data row4 col1" >at://did:plc:izxpomdyri45gzhppiiyattq/app.bsky.feed.post/3lhekdvrxj22j</td>
#       <td id="T_1f244_row4_col2" class="data row4 col2" >Honestly can't wait til my kid says bruh to me</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f244_row5_col0" class="data row5 col0" >2025-02-04T17:16:51.392Z</td>
#       <td id="T_1f244_row5_col1" class="data row5 col1" >at://did:plc:qw4sx3aio4hydfpmwkobfr53/app.bsky.feed.post/3lhekqfsyd22c</td>
#       <td id="T_1f244_row5_col2" class="data row5 col2" >Naw bruh Cam'ron gone mistake you for that nigga lmaooo</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f244_row6_col0" class="data row6 col0" >2025-02-04T17:17:31.688Z</td>
#       <td id="T_1f244_row6_col1" class="data row6 col1" >at://did:plc:d3e7nmgzhee6zbr36vpp5f7r/app.bsky.feed.post/3lhekri5ml22p</td>
#       <td id="T_1f244_row6_col2" class="data row6 col2" >Bruh istgg these mfs be saying anything they can think of that isn't "where are you" 💀</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1f244_row7_col0" class="data row7 col0" >2025-02-04T17:18:23.405Z</td>
#       <td id="T_1f244_row7_col1" class="data row7 col1" >at://did:plc:gvwzq4j2zfxxolxl7ekezpvk/app.bsky.feed.post/3lhekt5acxs2y</td>
#       <td id="T_1f244_row7_col2" class="data row7 col2" >//bruh i've actually been trying to cool down my horny roll ngl, this shit's getting samey
#
# but also lol funni smut</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1f244_row8_col0" class="data row8 col0" >2025-02-04T17:20:54.901Z</td>
#       <td id="T_1f244_row8_col1" class="data row8 col1" >at://did:plc:cpfybp6ugjvpds4jy3snmrca/app.bsky.feed.post/3lhekxlgy2s2c</td>
#       <td id="T_1f244_row8_col2" class="data row8 col2" >stood up and pain shot down the back of my hip and leg im 22 bruh can my body not fall apart already</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1f244_row9_col0" class="data row9 col0" >2025-02-04T17:30:37.677Z</td>
#       <td id="T_1f244_row9_col1" class="data row9 col1" >at://did:plc:wj4s7p6rvcgucx7jjspr4suw/app.bsky.feed.post/3lheliwscok2v</td>
#       <td id="T_1f244_row9_col2" class="data row9 col2" >Bruh Sinatra is giving Elon. 😞 she got to gooooo</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1f244_row10_col0" class="data row10 col0" >2025-02-04T17:47:45.772Z</td>
#       <td id="T_1f244_row10_col1" class="data row10 col1" >at://did:plc:77unrt5f3pk4vak3afxax74g/app.bsky.feed.post/3lhemhnitqk2g</td>
#       <td id="T_1f244_row10_col2" class="data row10 col2" >bruh can all of the "not funny didn't laugh" type mfs just fuck off yeah it ain't your humor but blah blah blah let a man make a joke fr 🙏🙏</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1f244_row11_col0" class="data row11 col0" >2025-02-04T17:49:27.811Z</td>
#       <td id="T_1f244_row11_col1" class="data row11 col1" >at://did:plc:33vbrmkvqztb3hjets7qvgbi/app.bsky.feed.post/3lhemkotdsk24</td>
#       <td id="T_1f244_row11_col2" class="data row11 col2" >Bruh I knew what was happening here and it GRIPPED ME. If you ever do more of this one I will be first in line to read</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1f244_row12_col0" class="data row12 col0" >2025-02-04T17:53:35.816Z</td>
#       <td id="T_1f244_row12_col1" class="data row12 col1" >at://did:plc:5rcevp3cpkwifjnfjotmqdij/app.bsky.feed.post/3lhems2d6c22k</td>
#       <td id="T_1f244_row12_col2" class="data row12 col2" >genuinely sad about it seemingly becoming the standard that “the magic looking 4 pointed star gimmick” is becoming the universally understood symbol for “AI”. bruh don’t give me this shit unless you’re doing Real Sorcery not akinator for sentences</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1f244_row13_col0" class="data row13 col0" >2025-02-04T17:57:25.220Z</td>
#       <td id="T_1f244_row13_col1" class="data row13 col1" >at://did:plc:m5claqny5myae5dxtjnkhb7v/app.bsky.feed.post/3lhemywc3fs2v</td>
#       <td id="T_1f244_row13_col2" class="data row13 col2" >Bruh this goes so hard</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1f244_row14_col0" class="data row14 col0" >2025-02-04T18:02:32.920Z</td>
#       <td id="T_1f244_row14_col1" class="data row14 col1" >at://did:plc:z26rv4lrogeu6rltngrksipv/app.bsky.feed.post/3lhenc3exgk2t</td>
#       <td id="T_1f244_row14_col2" class="data row14 col2" >Bruh you ain't even a mall cop.
#
# You corporate guys deal with nothing like that.</td>
#     </tr>
#     <tr>
#       <th id="T_1f244_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1f244_row15_col0" class="data row15 col0" >2025-02-04T18:14:16.408Z</td>
#       <td id="T_1f244_row15_col1" class="data row15 col1" >at://did:plc:vgj5hvui5eohkoo4za26iduk/app.bsky.feed.post/3lhenx2yunc26</td>
#       <td id="T_1f244_row15_col2" class="data row15 col2"

# %% [markdown]
# ## Prettify the data
# Let's find some ways to make the data a little more presentable. Let's get real URLs, a cleaner timestamp, and highlight the word.

# %%
from src.notebook_helpers import make_link
from src.notebook_helpers import prettify_time
from src.notebook_helpers import mark

# %%
highlight = lambda s: f'{mark(s, "(bru+h+)")}'

# %%
pretty_data = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)

pretty_data = pretty_data.reset_index(drop=True)

pretty_data.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d4ce">
#   <caption>Showing 288 of 3207 instances of bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d4ce_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_0d4ce_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_0d4ce_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d4ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d4ce_row0_col0" class="data row0 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_0d4ce_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:qeld3yz6jsokau6vnwapubtz/post/3lhejxvxv5c2q">Post</a></td>
#       <td id="T_0d4ce_row0_col2" class="data row0 col2" ><mark>Bruh</mark> im just tryna wallow in sadness why is that so hard nowadays</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d4ce_row1_col0" class="data row1 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_0d4ce_row1_col1" class="data row1 col1" ><a href="https://bsky.app/profile/did:plc:bbeqyegnad5xy2nl6n5iw3zy/post/3lhek3c2mtc26">Post</a></td>
#       <td id="T_0d4ce_row1_col2" class="data row1 col2" ><mark>bruh</mark> finding somewhere to sit on my campus on my fav building is impossible im gonna die before i even get to one spot</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d4ce_row2_col0" class="data row2 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_0d4ce_row2_col1" class="data row2 col1" ><a href="https://bsky.app/profile/did:plc:52bxkk7kixdpzgsile72ukcl/post/3lhek4lkg3k2q">Post</a></td>
#       <td id="T_0d4ce_row2_col2" class="data row2 col2" ><mark>Bruh</mark> they sold crack to black neighborhoods and played an active part in the 80s drug trade. They was never it to begin with!</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d4ce_row3_col0" class="data row3 col0" >Feb 04, 2025 05:07PM</td>
#       <td id="T_0d4ce_row3_col1" class="data row3 col1" ><a href="https://bsky.app/profile/did:plc:iixel3uapg43q4unbjx4a726/post/3lhek754fmk25">Post</a></td>
#       <td id="T_0d4ce_row3_col2" class="data row3 col2" ><mark>bruh</mark> if you don’t want to crawl inside of my skin then please leave me alone, I’m so tired of this nonchalant shit like do you fw me or not</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d4ce_row4_col0" class="data row4 col0" >Feb 04, 2025 05:09PM</td>
#       <td id="T_0d4ce_row4_col1" class="data row4 col1" ><a href="https://bsky.app/profile/did:plc:izxpomdyri45gzhppiiyattq/post/3lhekdvrxj22j">Post</a></td>
#       <td id="T_0d4ce_row4_col2" class="data row4 col2" >Honestly can&#39;t wait til my kid says <mark>bruh</mark> to me</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d4ce_row5_col0" class="data row5 col0" >Feb 04, 2025 05:16PM</td>
#       <td id="T_0d4ce_row5_col1" class="data row5 col1" ><a href="https://bsky.app/profile/did:plc:qw4sx3aio4hydfpmwkobfr53/post/3lhekqfsyd22c">Post</a></td>
#       <td id="T_0d4ce_row5_col2" class="data row5 col2" >Naw <mark>bruh</mark> Cam&#39;ron gone mistake you for that nigga lmaooo</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d4ce_row6_col0" class="data row6 col0" >Feb 04, 2025 05:17PM</td>
#       <td id="T_0d4ce_row6_col1" class="data row6 col1" ><a href="https://bsky.app/profile/did:plc:d3e7nmgzhee6zbr36vpp5f7r/post/3lhekri5ml22p">Post</a></td>
#       <td id="T_0d4ce_row6_col2" class="data row6 col2" ><mark>Bruh</mark> istgg these mfs be saying anything they can think of that isn&#39;t &#34;where are you&#34; 💀</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d4ce_row7_col0" class="data row7 col0" >Feb 04, 2025 05:18PM</td>
#       <td id="T_0d4ce_row7_col1" class="data row7 col1" ><a href="https://bsky.app/profile/did:plc:gvwzq4j2zfxxolxl7ekezpvk/post/3lhekt5acxs2y">Post</a></td>
#       <td id="T_0d4ce_row7_col2" class="data row7 col2" >//<mark>bruh</mark> i&#39;ve actually been trying to cool down my horny roll ngl, this shit&#39;s getting samey
#
# but also lol funni smut</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0d4ce_row8_col0" class="data row8 col0" >Feb 04, 2025 05:20PM</td>
#       <td id="T_0d4ce_row8_col1" class="data row8 col1" ><a href="https://bsky.app/profile/did:plc:cpfybp6ugjvpds4jy3snmrca/post/3lhekxlgy2s2c">Post</a></td>
#       <td id="T_0d4ce_row8_col2" class="data row8 col2" >stood up and pain shot down the back of my hip and leg im 22 <mark>bruh</mark> can my body not fall apart already</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0d4ce_row9_col0" class="data row9 col0" >Feb 04, 2025 05:30PM</td>
#       <td id="T_0d4ce_row9_col1" class="data row9 col1" ><a href="https://bsky.app/profile/did:plc:wj4s7p6rvcgucx7jjspr4suw/post/3lheliwscok2v">Post</a></td>
#       <td id="T_0d4ce_row9_col2" class="data row9 col2" ><mark>Bruh</mark> Sinatra is giving Elon. 😞 she got to gooooo</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0d4ce_row10_col0" class="data row10 col0" >Feb 04, 2025 05:47PM</td>
#       <td id="T_0d4ce_row10_col1" class="data row10 col1" ><a href="https://bsky.app/profile/did:plc:77unrt5f3pk4vak3afxax74g/post/3lhemhnitqk2g">Post</a></td>
#       <td id="T_0d4ce_row10_col2" class="data row10 col2" ><mark>bruh</mark> can all of the &#34;not funny didn&#39;t laugh&#34; type mfs just fuck off yeah it ain&#39;t your humor but blah blah blah let a man make a joke fr 🙏🙏</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0d4ce_row11_col0" class="data row11 col0" >Feb 04, 2025 05:49PM</td>
#       <td id="T_0d4ce_row11_col1" class="data row11 col1" ><a href="https://bsky.app/profile/did:plc:33vbrmkvqztb3hjets7qvgbi/post/3lhemkotdsk24">Post</a></td>
#       <td id="T_0d4ce_row11_col2" class="data row11 col2" ><mark>Bruh</mark> I knew what was happening here and it GRIPPED ME. If you ever do more of this one I will be first in line to read</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0d4ce_row12_col0" class="data row12 col0" >Feb 04, 2025 05:53PM</td>
#       <td id="T_0d4ce_row12_col1" class="data row12 col1" ><a href="https://bsky.app/profile/did:plc:5rcevp3cpkwifjnfjotmqdij/post/3lhems2d6c22k">Post</a></td>
#       <td id="T_0d4ce_row12_col2" class="data row12 col2" >genuinely sad about it seemingly becoming the standard that “the magic looking 4 pointed star gimmick” is becoming the universally understood symbol for “AI”. <mark>bruh</mark> don’t give me this shit unless you’re doing Real Sorcery not akinator for sentences</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0d4ce_row13_col0" class="data row13 col0" >Feb 04, 2025 05:57PM</td>
#       <td id="T_0d4ce_row13_col1" class="data row13 col1" ><a href="https://bsky.app/profile/did:plc:m5claqny5myae5dxtjnkhb7v/post/3lhemywc3fs2v">Post</a></td>
#       <td id="T_0d4ce_row13_col2" class="data row13 col2" ><mark>Bruh</mark> this goes so hard</td>
#     </tr>
#     <tr>
#       <th id="T_0d4ce_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0d4ce_row14_col0" class="data row14 col0" >Feb 04, 2025 06:02PM</td>
#       <td id="T_0d4ce_row14_col1" class="data row14 col1" ><a href="https://bsky.app/profile/did:plc:z26rv4lrogeu6rltngrksipv/

# %% [markdown]
# ## Now let's look at some sentiment

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
rows_with_sentiment = []
column_titles = ['Time', 'URI', 'Post Text', 'Negative', 'Neutral', 'Positive', 'Compound']

neg_count = 0
pos_count = 0
neu_count = 0
for row in pronoun_rows:
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(row[2])
    row_as_list = list(row)
    row_as_list.append(ss['neg'])
    neg_count += ss['neg']
    row_as_list.append(ss['neu'])
    neu_count += ss['neu']
    row_as_list.append(ss['pos'])
    pos_count += ss['pos']
    row_as_list.append(ss['compound'])
    rows_with_sentiment.append(row_as_list)



pretty_sentiment = pd.DataFrame(rows_with_sentiment[0:raw_slice_size], columns=column_titles)

ps = pretty_sentiment.reset_index(drop=True)

ps.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc8b7">
#   <caption>Showing 288 of 3207 instances of bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc8b7_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_fc8b7_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_fc8b7_level0_col2" class="col_heading level0 col2" >Post Text</th>
#       <th id="T_fc8b7_level0_col3" class="col_heading level0 col3" >Negative</th>
#       <th id="T_fc8b7_level0_col4" class="col_heading level0 col4" >Neutral</th>
#       <th id="T_fc8b7_level0_col5" class="col_heading level0 col5" >Positive</th>
#       <th id="T_fc8b7_level0_col6" class="col_heading level0 col6" >Compound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc8b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc8b7_row0_col0" class="data row0 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_fc8b7_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:qeld3yz6jsokau6vnwapubtz/post/3lhejxvxv5c2q">Post</a></td>
#       <td id="T_fc8b7_row0_col2" class="data row0 col2" ><mark>Bruh</mark> im just tryna wallow in sadness why is that so hard nowadays</td>
#       <td id="T_fc8b7_row0_col3" class="data row0 col3" >0.302000</td>
#       <td id="T_fc8b7_row0_col4" class="data row0 col4" >0.698000</td>
#       <td id="T_fc8b7_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_fc8b7_row0_col6" class="data row0 col6" >-0.581200</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc8b7_row1_col0" class="data row1 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_fc8b7_row1_col1" class="data row1 col1" ><a href="https://bsky.app/profile/did:plc:bbeqyegnad5xy2nl6n5iw3zy/post/3lhek3c2mtc26">Post</a></td>
#       <td id="T_fc8b7_row1_col2" class="data row1 col2" ><mark>bruh</mark> finding somewhere to sit on my campus on my fav building is impossible im gonna die before i even get to one spot</td>
#       <td id="T_fc8b7_row1_col3" class="data row1 col3" >0.140000</td>
#       <td id="T_fc8b7_row1_col4" class="data row1 col4" >0.753000</td>
#       <td id="T_fc8b7_row1_col5" class="data row1 col5" >0.108000</td>
#       <td id="T_fc8b7_row1_col6" class="data row1 col6" >-0.226300</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc8b7_row2_col0" class="data row2 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_fc8b7_row2_col1" class="data row2 col1" ><a href="https://bsky.app/profile/did:plc:52bxkk7kixdpzgsile72ukcl/post/3lhek4lkg3k2q">Post</a></td>
#       <td id="T_fc8b7_row2_col2" class="data row2 col2" ><mark>Bruh</mark> they sold crack to black neighborhoods and played an active part in the 80s drug trade. They was never it to begin with!</td>
#       <td id="T_fc8b7_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_fc8b7_row2_col4" class="data row2 col4" >0.803000</td>
#       <td id="T_fc8b7_row2_col5" class="data row2 col5" >0.197000</td>
#       <td id="T_fc8b7_row2_col6" class="data row2 col6" >0.658800</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc8b7_row3_col0" class="data row3 col0" >Feb 04, 2025 05:07PM</td>
#       <td id="T_fc8b7_row3_col1" class="data row3 col1" ><a href="https://bsky.app/profile/did:plc:iixel3uapg43q4unbjx4a726/post/3lhek754fmk25">Post</a></td>
#       <td id="T_fc8b7_row3_col2" class="data row3 col2" ><mark>bruh</mark> if you don’t want to crawl inside of my skin then please leave me alone, I’m so tired of this nonchalant shit like do you fw me or not</td>
#       <td id="T_fc8b7_row3_col3" class="data row3 col3" >0.256000</td>
#       <td id="T_fc8b7_row3_col4" class="data row3 col4" >0.588000</td>
#       <td id="T_fc8b7_row3_col5" class="data row3 col5" >0.156000</td>
#       <td id="T_fc8b7_row3_col6" class="data row3 col6" >-0.598400</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc8b7_row4_col0" class="data row4 col0" >Feb 04, 2025 05:09PM</td>
#       <td id="T_fc8b7_row4_col1" class="data row4 col1" ><a href="https://bsky.app/profile/did:plc:izxpomdyri45gzhppiiyattq/post/3lhekdvrxj22j">Post</a></td>
#       <td id="T_fc8b7_row4_col2" class="data row4 col2" >Honestly can&#39;t wait til my kid says <mark>bruh</mark> to me</td>
#       <td id="T_fc8b7_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_fc8b7_row4_col4" class="data row4 col4" >0.750000</td>
#       <td id="T_fc8b7_row4_col5" class="data row4 col5" >0.250000</td>
#       <td id="T_fc8b7_row4_col6" class="data row4 col6" >0.458800</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc8b7_row5_col0" class="data row5 col0" >Feb 04, 2025 05:16PM</td>
#       <td id="T_fc8b7_row5_col1" class="data row5 col1" ><a href="https://bsky.app/profile/did:plc:qw4sx3aio4hydfpmwkobfr53/post/3lhekqfsyd22c">Post</a></td>
#       <td id="T_fc8b7_row5_col2" class="data row5 col2" >Naw <mark>bruh</mark> Cam&#39;ron gone mistake you for that nigga lmaooo</td>
#       <td id="T_fc8b7_row5_col3" class="data row5 col3" >0.211000</td>
#       <td id="T_fc8b7_row5_col4" class="data row5 col4" >0.789000</td>
#       <td id="T_fc8b7_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_fc8b7_row5_col6" class="data row5 col6" >-0.340000</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc8b7_row6_col0" class="data row6 col0" >Feb 04, 2025 05:17PM</td>
#       <td id="T_fc8b7_row6_col1" class="data row6 col1" ><a href="https://bsky.app/profile/did:plc:d3e7nmgzhee6zbr36vpp5f7r/post/3lhekri5ml22p">Post</a></td>
#       <td id="T_fc8b7_row6_col2" class="data row6 col2" ><mark>Bruh</mark> istgg these mfs be saying anything they can think of that isn&#39;t &#34;where are you&#34; 💀</td>
#       <td id="T_fc8b7_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_fc8b7_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_fc8b7_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_fc8b7_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc8b7_row7_col0" class="data row7 col0" >Feb 04, 2025 05:18PM</td>
#       <td id="T_fc8b7_row7_col1" class="data row7 col1" ><a href="https://bsky.app/profile/did:plc:gvwzq4j2zfxxolxl7ekezpvk/post/3lhekt5acxs2y">Post</a></td>
#       <td id="T_fc8b7_row7_col2" class="data row7 col2" >//<mark>bruh</mark> i&#39;ve actually been trying to cool down my horny roll ngl, this shit&#39;s getting samey
#
# but also lol funni smut</td>
#       <td id="T_fc8b7_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_fc8b7_row7_col4" class="data row7 col4" >0.780000</td>
#       <td id="T_fc8b7_row7_col5" class="data row7 col5" >0.220000</td>
#       <td id="T_fc8b7_row7_col6" class="data row7 col6" >0.654200</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc8b7_row8_col0" class="data row8 col0" >Feb 04, 2025 05:20PM</td>
#       <td id="T_fc8b7_row8_col1" class="data row8 col1" ><a href="https://bsky.app/profile/did:plc:cpfybp6ugjvpds4jy3snmrca/post/3lhekxlgy2s2c">Post</a></td>
#       <td id="T_fc8b7_row8_col2" class="data row8 col2" >stood up and pain shot down the back of my hip and leg im 22 <mark>bruh</mark> can my body not fall apart already</td>
#       <td id="T_fc8b7_row8_col3" class="data row8 col3" >0.130000</td>
#       <td id="T_fc8b7_row8_col4" class="data row8 col4" >0.870000</td>
#       <td id="T_fc8b7_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_fc8b7_row8_col6" class="data row8 col6" >-0.510600</td>
#     </tr>
#     <tr>
#       <th id="T_fc8b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <

# %%
mean_neg = neg_count / len(pronoun_rows)
mean_pos = pos_count / len(pronoun_rows)
mean_neu = neu_count / len(pronoun_rows)

print(f"""
Mean Negative Sentiment {mean_neg}
Mean Positive Sentiment {mean_pos}
Mean Neutral Sentiment {mean_neu}
""")
# Out:
# Mean Negative Sentiment 0.11880947926410969
# Mean Positive Sentiment 0.0988889928281885
# Mean Neutral Sentiment 0.7822912379170557

# %%
from src.notebook_helpers import get_frequency_dict, get_instance_dict
from src.regexes import PROFANITY_REGEX
from src.regexes import AFFIRMATION_REGEX
from src.regexes import NEGATION_REGEX
from src.regexes import EMOJI_REGEX

# %% [markdown]
# Note:
#
# not just mean
# Use standard deviation
# use distribution
# consider a T-Test (1 tailed or 2-tailed)
# consult Natasha Warner

# %%
negations = get_frequency_dict(pronoun_rows, NEGATION_REGEX)
affirmations = get_frequency_dict(pronoun_rows, AFFIRMATION_REGEX)
profanities = get_frequency_dict(pronoun_rows, PROFANITY_REGEX)
emojis = get_frequency_dict(pronoun_rows, EMOJI_REGEX)

# %%
total_negations = sum( v for k,v in negations.items() )
total_affirmations =  sum( v for k,v in affirmations.items() )
total_profanities = sum( v for k,v in affirmations.items() )
total_emojis = sum(v for k,v in emojis.items() )

# %%
negation_density = get_instance_dict(negations.keys(), pronoun_rows)
total_neg_posts = sum( v for k,v in negation_density.items() )

neg_table = pd.DataFrame(negations.items(), columns=['Negation', 'Total Occurences'])
neg_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
nt = neg_table.reset_index(drop=True)

nt['Posts with One'] = nt['Negation'].map(negation_density)
nt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_negations} negations from {total_neg_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_de93e">
#   <caption>Showing 192 negations from 185 posts using bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de93e_level0_col0" class="col_heading level0 col0" >Negation</th>
#       <th id="T_de93e_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_de93e_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de93e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de93e_row0_col0" class="data row0 col0" >no</td>
#       <td id="T_de93e_row0_col1" class="data row0 col1" >146</td>
#       <td id="T_de93e_row0_col2" class="data row0 col2" >140</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de93e_row1_col0" class="data row1 col0" >nah</td>
#       <td id="T_de93e_row1_col1" class="data row1 col1" >31</td>
#       <td id="T_de93e_row1_col2" class="data row1 col2" >30</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_de93e_row2_col0" class="data row2 col0" >naw</td>
#       <td id="T_de93e_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_de93e_row2_col2" class="data row2 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_de93e_row3_col0" class="data row3 col0" >noooo</td>
#       <td id="T_de93e_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_de93e_row3_col2" class="data row3 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_de93e_row4_col0" class="data row4 col0" >nope</td>
#       <td id="T_de93e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_de93e_row4_col2" class="data row4 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_de93e_row5_col0" class="data row5 col0" >nuh</td>
#       <td id="T_de93e_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_de93e_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_de93e_row6_col0" class="data row6 col0" >nooooooo</td>
#       <td id="T_de93e_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_de93e_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_de93e_row7_col0" class="data row7 col0" >naaaaaaaaaah</td>
#       <td id="T_de93e_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_de93e_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_de93e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_de93e_row8_col0" class="data row8 col0" >nooooo</td>
#       <td id="T_de93e_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_de93e_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# make sure to use distributions here.

# %%
aff_density = get_instance_dict(affirmations.keys(), pronoun_rows)
total_aff_posts = sum( v for k,v in aff_density.items() )

aff_table = pd.DataFrame(affirmations.items(), columns=['Affirmation', 'Total Occurences'])
aff_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

at = aff_table.reset_index(drop=True)
at['Posts with One'] = at['Affirmation'].map(aff_density)

at.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_affirmations} affirmations from {total_aff_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_845ac">
#   <caption>Showing 96 affirmations from 93 posts using bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_845ac_level0_col0" class="col_heading level0 col0" >Affirmation</th>
#       <th id="T_845ac_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_845ac_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_845ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_845ac_row0_col0" class="data row0 col0" >yeah</td>
#       <td id="T_845ac_row0_col1" class="data row0 col1" >29</td>
#       <td id="T_845ac_row0_col2" class="data row0 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_845ac_row1_col0" class="data row1 col0" >ya</td>
#       <td id="T_845ac_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_845ac_row1_col2" class="data row1 col2" >22</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_845ac_row2_col0" class="data row2 col0" >yes</td>
#       <td id="T_845ac_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_845ac_row2_col2" class="data row2 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_845ac_row3_col0" class="data row3 col0" >yea</td>
#       <td id="T_845ac_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_845ac_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_845ac_row4_col0" class="data row4 col0" >yep</td>
#       <td id="T_845ac_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_845ac_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_845ac_row5_col0" class="data row5 col0" >yay</td>
#       <td id="T_845ac_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_845ac_row5_col2" class="data row5 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_845ac_row6_col0" class="data row6 col0" >ye</td>
#       <td id="T_845ac_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_845ac_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_845ac_row7_col0" class="data row7 col0" >yeaaaaah</td>
#       <td id="T_845ac_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_845ac_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_845ac_row8_col0" class="data row8 col0" >yap</td>
#       <td id="T_845ac_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_845ac_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_845ac_row9_col0" class="data row9 col0" >yeh</td>
#       <td id="T_845ac_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_845ac_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_845ac_row10_col0" class="data row10 col0" >yeaaa</td>
#       <td id="T_845ac_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_845ac_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_845ac_row11_col0" class="data row11 col0" >yup</td>
#       <td id="T_845ac_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_845ac_row11_col2" class="data row11 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_845ac_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_845ac_row12_col0" class="data row12 col0" >yeaaaa</td>
#       <td id="T_845ac_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_845ac_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
prof_density = get_instance_dict(profanities.keys(), pronoun_rows)
total_prof_posts = sum( v for k,v in prof_density.items() )

prof_table = pd.DataFrame(profanities.items(), columns=['Profanity', 'Total Occurences'])
prof_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

pt = prof_table.reset_index(drop=True)
pt['Posts with One'] = pt['Profanity'].map(prof_density)

pt.style\
    .set_caption(f"Showing {total_profanities} profanities from {total_prof_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9cb1">
#   <caption>Showing 96 profanities from 987 posts using bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9cb1_level0_col0" class="col_heading level0 col0" >Profanity</th>
#       <th id="T_f9cb1_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_f9cb1_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9cb1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9cb1_row0_col0" class="data row0 col0" >shit</td>
#       <td id="T_f9cb1_row0_col1" class="data row0 col1" >212</td>
#       <td id="T_f9cb1_row0_col2" class="data row0 col2" >198</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9cb1_row1_col0" class="data row1 col0" >ass</td>
#       <td id="T_f9cb1_row1_col1" class="data row1 col1" >191</td>
#       <td id="T_f9cb1_row1_col2" class="data row1 col2" >85</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9cb1_row2_col0" class="data row2 col0" >fucking</td>
#       <td id="T_f9cb1_row2_col1" class="data row2 col1" >142</td>
#       <td id="T_f9cb1_row2_col2" class="data row2 col2" >135</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9cb1_row3_col0" class="data row3 col0" >fuck</td>
#       <td id="T_f9cb1_row3_col1" class="data row3 col1" >123</td>
#       <td id="T_f9cb1_row3_col2" class="data row3 col2" >115</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9cb1_row4_col0" class="data row4 col0" >wtf</td>
#       <td id="T_f9cb1_row4_col1" class="data row4 col1" >86</td>
#       <td id="T_f9cb1_row4_col2" class="data row4 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9cb1_row5_col0" class="data row5 col0" >damn</td>
#       <td id="T_f9cb1_row5_col1" class="data row5 col1" >52</td>
#       <td id="T_f9cb1_row5_col2" class="data row5 col2" >52</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f9cb1_row6_col0" class="data row6 col0" >fucked</td>
#       <td id="T_f9cb1_row6_col1" class="data row6 col1" >33</td>
#       <td id="T_f9cb1_row6_col2" class="data row6 col2" >27</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f9cb1_row7_col0" class="data row7 col0" >fuckin</td>
#       <td id="T_f9cb1_row7_col1" class="data row7 col1" >24</td>
#       <td id="T_f9cb1_row7_col2" class="data row7 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f9cb1_row8_col0" class="data row8 col0" >lmfao</td>
#       <td id="T_f9cb1_row8_col1" class="data row8 col1" >19</td>
#       <td id="T_f9cb1_row8_col2" class="data row8 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f9cb1_row9_col0" class="data row9 col0" >bull</td>
#       <td id="T_f9cb1_row9_col1" class="data row9 col1" >14</td>
#       <td id="T_f9cb1_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f9cb1_row10_col0" class="data row10 col0" >stfu</td>
#       <td id="T_f9cb1_row10_col1" class="data row10 col1" >9</td>
#       <td id="T_f9cb1_row10_col2" class="data row10 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f9cb1_row11_col0" class="data row11 col0" >asshole</td>
#       <td id="T_f9cb1_row11_col1" class="data row11 col1" >6</td>
#       <td id="T_f9cb1_row11_col2" class="data row11 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f9cb1_row12_col0" class="data row12 col0" >god</td>
#       <td id="T_f9cb1_row12_col1" class="data row12 col1" >6</td>
#       <td id="T_f9cb1_row12_col2" class="data row12 col2" >35</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f9cb1_row13_col0" class="data row13 col0" >omfg</td>
#       <td id="T_f9cb1_row13_col1" class="data row13 col1" >5</td>
#       <td id="T_f9cb1_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f9cb1_row14_col0" class="data row14 col0" >dick</td>
#       <td id="T_f9cb1_row14_col1" class="data row14 col1" >4</td>
#       <td id="T_f9cb1_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f9cb1_row15_col0" class="data row15 col0" >shitty</td>
#       <td id="T_f9cb1_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_f9cb1_row15_col2" class="data row15 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f9cb1_row16_col0" class="data row16 col0" >dip</td>
#       <td id="T_f9cb1_row16_col1" class="data row16 col1" >3</td>
#       <td id="T_f9cb1_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f9cb1_row17_col0" class="data row17 col0" >mother</td>
#       <td id="T_f9cb1_row17_col1" class="data row17 col1" >2</td>
#       <td id="T_f9cb1_row17_col2" class="data row17 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f9cb1_row18_col0" class="data row18 col0" >shits</td>
#       <td id="T_f9cb1_row18_col1" class="data row18 col1" >2</td>
#       <td id="T_f9cb1_row18_col2" class="data row18 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f9cb1_row19_col0" class="data row19 col0" >dog</td>
#       <td id="T_f9cb1_row19_col1" class="data row19 col1" >2</td>
#       <td id="T_f9cb1_row19_col2" class="data row19 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f9cb1_row20_col0" class="data row20 col0" >cock</td>
#       <td id="T_f9cb1_row20_col1" class="data row20 col1" >2</td>
#       <td id="T_f9cb1_row20_col2" class="data row20 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f9cb1_row21_col0" class="data row21 col0" >fucker</td>
#       <td id="T_f9cb1_row21_col1" class="data row21 col1" >2</td>
#       <td id="T_f9cb1_row21_col2" class="data row21 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f9cb1_row22_col0" class="data row22 col0" >dicks</td>
#       <td id="T_f9cb1_row22_col1" class="data row22 col1" >2</td>
#       <td id="T_f9cb1_row22_col2" class="data row22 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f9cb1_row23_col0" class="data row23 col0" >damned</td>
#       <td id="T_f9cb1_row23_col1" class="data row23 col1" >2</td>
#       <td id="T_f9cb1_row23_col2" class="data row23 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f9cb1_row24_col0" class="data row24 col0" >shittified</td>
#       <td id="T_f9cb1_row24_col1" class="data row24 col1" >1</td>
#       <td id="T_f9cb1_row24_col2" class="data row24 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f9cb1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f9cb1_ro

# %%
e_density = get_instance_dict(emojis.keys(), pronoun_rows)
total_e_posts = sum( v for k,v in aff_density.items() )

emoji_table = pd.DataFrame(emojis.items(), columns=['Emoji', 'Total Occurences'])
emoji_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
et = emoji_table.reset_index(drop=True)
et['Posts with One'] = et['Emoji'].map(e_density)

et.style\
    .set_caption(f"Showing {total_negations} emojis from {total_e_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc329">
#   <caption>Showing 192 emojis from 93 posts using bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc329_level0_col0" class="col_heading level0 col0" >Emoji</th>
#       <th id="T_fc329_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_fc329_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc329_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc329_row0_col0" class="data row0 col0" >😭</td>
#       <td id="T_fc329_row0_col1" class="data row0 col1" >689</td>
#       <td id="T_fc329_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc329_row1_col0" class="data row1 col0" >😂</td>
#       <td id="T_fc329_row1_col1" class="data row1 col1" >292</td>
#       <td id="T_fc329_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc329_row2_col0" class="data row2 col0" >💀</td>
#       <td id="T_fc329_row2_col1" class="data row2 col1" >132</td>
#       <td id="T_fc329_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc329_row3_col0" class="data row3 col0" >🤣</td>
#       <td id="T_fc329_row3_col1" class="data row3 col1" >128</td>
#       <td id="T_fc329_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc329_row4_col0" class="data row4 col0" >😨</td>
#       <td id="T_fc329_row4_col1" class="data row4 col1" >39</td>
#       <td id="T_fc329_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc329_row5_col0" class="data row5 col0" >💔</td>
#       <td id="T_fc329_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_fc329_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc329_row6_col0" class="data row6 col0" >🤦</td>
#       <td id="T_fc329_row6_col1" class="data row6 col1" >28</td>
#       <td id="T_fc329_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc329_row7_col0" class="data row7 col0" >🔥</td>
#       <td id="T_fc329_row7_col1" class="data row7 col1" >27</td>
#       <td id="T_fc329_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc329_row8_col0" class="data row8 col0" >🏾</td>
#       <td id="T_fc329_row8_col1" class="data row8 col1" >25</td>
#       <td id="T_fc329_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc329_row9_col0" class="data row9 col0" >😩</td>
#       <td id="T_fc329_row9_col1" class="data row9 col1" >24</td>
#       <td id="T_fc329_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc329_row10_col0" class="data row10 col0" >😔</td>
#       <td id="T_fc329_row10_col1" class="data row10 col1" >19</td>
#       <td id="T_fc329_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc329_row11_col0" class="data row11 col0" >🫠</td>
#       <td id="T_fc329_row11_col1" class="data row11 col1" >18</td>
#       <td id="T_fc329_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fc329_row12_col0" class="data row12 col0" >😫</td>
#       <td id="T_fc329_row12_col1" class="data row12 col1" >17</td>
#       <td id="T_fc329_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fc329_row13_col0" class="data row13 col0" >😳</td>
#       <td id="T_fc329_row13_col1" class="data row13 col1" >17</td>
#       <td id="T_fc329_row13_col2" class="data row13 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fc329_row14_col0" class="data row14 col0" >🙏</td>
#       <td id="T_fc329_row14_col1" class="data row14 col1" >16</td>
#       <td id="T_fc329_row14_col2" class="data row14 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fc329_row15_col0" class="data row15 col0" >🙄</td>
#       <td id="T_fc329_row15_col1" class="data row15 col1" >16</td>
#       <td id="T_fc329_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fc329_row16_col0" class="data row16 col0" >😒</td>
#       <td id="T_fc329_row16_col1" class="data row16 col1" >15</td>
#       <td id="T_fc329_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fc329_row17_col0" class="data row17 col0" >😅</td>
#       <td id="T_fc329_row17_col1" class="data row17 col1" >14</td>
#       <td id="T_fc329_row17_col2" class="data row17 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fc329_row18_col0" class="data row18 col0" >🥲</td>
#       <td id="T_fc329_row18_col1" class="data row18 col1" >13</td>
#       <td id="T_fc329_row18_col2" class="data row18 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fc329_row19_col0" class="data row19 col0" >😮</td>
#       <td id="T_fc329_row19_col1" class="data row19 col1" >12</td>
#       <td id="T_fc329_row19_col2" class="data row19 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fc329_row20_col0" class="data row20 col0" >🙃</td>
#       <td id="T_fc329_row20_col1" class="data row20 col1" >11</td>
#       <td id="T_fc329_row20_col2" class="data row20 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fc329_row21_col0" class="data row21 col0" >😆</td>
#       <td id="T_fc329_row21_col1" class="data row21 col1" >11</td>
#       <td id="T_fc329_row21_col2" class="data row21 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fc329_row22_col0" class="data row22 col0" >🤷</td>
#       <td id="T_fc329_row22_col1" class="data row22 col1" >11</td>
#       <td id="T_fc329_row22_col2" class="data row22 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fc329_row23_col0" class="data row23 col0" >🥹</td>
#       <td id="T_fc329_row23_col1" class="data row23 col1" >10</td>
#       <td id="T_fc329_row23_col2" class="data row23 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fc329_row24_col0" class="data row24 col0" >🏻</td>
#       <td id="T_fc329_row24_col1" class="data row24 col1" >10</td>
#       <td id="T_fc329_row24_col2" class="data row24 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc329_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_fc329_row25_col0" class="data row25 col0" >💨</td>
#       <td id="T_fc329_row25_col1" class="data row25 col1" >10</

# %% [markdown]
# ## Associated Pronouns

# %% [markdown]
# statistical test for comparing ranked items on a list
# use that for comparing emojis
# spearman rank?

# %%
from nltk.tokenize import word_tokenize
from collections import Counter


associate_pronouns = Counter()
for row in pronoun_rows:
    text = row[2]
    tokens = word_tokenize(text)
    poss = nltk.pos_tag(tokens)
    for pos in poss:
        tok,p = pos
        if p == 'PRP$':
            associate_pronouns.update([tok.lower()])

total_pronouns = sum( v for k,v in associate_pronouns.items() )
p_density = get_instance_dict(associate_pronouns.keys(), pronoun_rows)

pron_table = pd.DataFrame(associate_pronouns.items(), columns=['Pronoun', 'Total Occurences'])
pron_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)


pt = pron_table.reset_index(drop=True)
pt['Posts with One'] = pt['Pronoun'].map(p_density)

pt.style\
    .set_caption(f"Showing {total_pronouns} pronouns that were used with {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6691e">
#   <caption>Showing 1174 pronouns that were used with bruh</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6691e_level0_col0" class="col_heading level0 col0" >Pronoun</th>
#       <th id="T_6691e_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_6691e_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6691e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6691e_row0_col0" class="data row0 col0" >my</td>
#       <td id="T_6691e_row0_col1" class="data row0 col1" >669</td>
#       <td id="T_6691e_row0_col2" class="data row0 col2" >586</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6691e_row1_col0" class="data row1 col0" >your</td>
#       <td id="T_6691e_row1_col1" class="data row1 col1" >143</td>
#       <td id="T_6691e_row1_col2" class="data row1 col2" >139</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6691e_row2_col0" class="data row2 col0" >his</td>
#       <td id="T_6691e_row2_col1" class="data row2 col1" >93</td>
#       <td id="T_6691e_row2_col2" class="data row2 col2" >87</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6691e_row3_col0" class="data row3 col0" >their</td>
#       <td id="T_6691e_row3_col1" class="data row3 col1" >89</td>
#       <td id="T_6691e_row3_col2" class="data row3 col2" >85</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6691e_row4_col0" class="data row4 col0" >her</td>
#       <td id="T_6691e_row4_col1" class="data row4 col1" >71</td>
#       <td id="T_6691e_row4_col2" class="data row4 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6691e_row5_col0" class="data row5 col0" >its</td>
#       <td id="T_6691e_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_6691e_row5_col2" class="data row5 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6691e_row6_col0" class="data row6 col0" >our</td>
#       <td id="T_6691e_row6_col1" class="data row6 col1" >39</td>
#       <td id="T_6691e_row6_col2" class="data row6 col2" >38</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6691e_row7_col0" class="data row7 col0" >hhhhh</td>
#       <td id="T_6691e_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_6691e_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6691e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6691e_row8_col0" class="data row8 col0" >you</td>
#       <td id="T_6691e_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_6691e_row8_col2" class="data row8 col2" >532</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Be sure to look for tech bro

# %% [markdown]
# First thing to do:
# define pronoun or "bronoun"
# be sure to acknowledge original research in paper
# journal of language and social psychology
# briefly touch on details for the presentation
#
# don't bore people too much
