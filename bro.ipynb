# %% [markdown]
# # Bro Analysis
#
# This is a file for analyzing the use of "bronouns" from a SQL database

# %% [markdown]
# ## Setup

# %%
# dependencies
import sqlite3
import math
import re
import nltk
import pandas as pd
from datetime import datetime

# %%
# Initialize DB
connection = sqlite3.connect('../db.pronouns.with-data.sqlite')
cursor = connection.cursor()

# %%
# Get the Rows
# Make columns and pronoun variables, so this is reusable
sql_columns = ['indexedAt','uri', 'text']
column_titles = ['Time', 'URI', 'Post Text'] # This is for Pandas, later down
pronoun = 'bro'
select_query = f"SELECT {','.join(sql_columns)} FROM post WHERE post.pronoun == '{pronoun}'"
cursor.execute(select_query)

pronoun_rows = cursor.fetchall()

# %% [markdown]
# ## Raw Data

# %%
# let's find out how many entries we have
size = len(pronoun_rows)

print(f"There are {size} instances of {pronoun}")
# Out:
# There are 21290 instances of bro

# %%
# Let's look at a row
print(pronoun_rows[0])
# Out:
# ('2025-02-04T17:02:30.996Z', 'at://did:plc:zljlg7cgdfsl7maqvjjpp7i4/app.bsky.feed.post/3lhejwqzwus2d', 'bro named his dog after william f buckley lmfaoo')

# %%
# We want to see some. But let's not blow it up
max_table_rows = int(size * .2)
raw_slice_size = int(max_table_rows * .2)

pd.set_option('display.max_rows', max_table_rows )
pd.set_option('display.max_colwidth', None)

# %%
raw_frame = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)
raw_frame.style\
    .hide(axis="index")\
    .set_caption(f"Showing {raw_slice_size} of {size}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c01bf">
#   <caption>Showing 851 of 21290</caption>
#   <thead>
#     <tr>
#       <th id="T_c01bf_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_c01bf_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_c01bf_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c01bf_row0_col0" class="data row0 col0" >2025-02-04T17:02:30.996Z</td>
#       <td id="T_c01bf_row0_col1" class="data row0 col1" >at://did:plc:zljlg7cgdfsl7maqvjjpp7i4/app.bsky.feed.post/3lhejwqzwus2d</td>
#       <td id="T_c01bf_row0_col2" class="data row0 col2" >bro named his dog after william f buckley lmfaoo</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row1_col0" class="data row1 col0" >2025-02-04T17:03:02.319Z</td>
#       <td id="T_c01bf_row1_col1" class="data row1 col1" >at://did:plc:a54rlrqaz5tupdleps5ygd2s/app.bsky.feed.post/3lhejxozykk24</td>
#       <td id="T_c01bf_row1_col2" class="data row1 col2" >How come I just saw my neighbor put a full trash bag on the hood of his car and drove it to the dumpster that way. Like bro was the smell that horrendous you refused to put it in ur car for 500 ft</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row2_col0" class="data row2 col0" >2025-02-04T17:03:05.614Z</td>
#       <td id="T_c01bf_row2_col1" class="data row2 col1" >at://did:plc:tusj3ujtamsxcxj5tfbe4jgd/app.bsky.feed.post/3lhejxrokmc26</td>
#       <td id="T_c01bf_row2_col2" class="data row2 col2" >Bro they aren’t done either 🤣
# They have 29 days to make another deal, and they have to show they actually secure their side.</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row3_col0" class="data row3 col0" >2025-02-04T17:03:41.435Z</td>
#       <td id="T_c01bf_row3_col1" class="data row3 col1" >at://did:plc:ozzimeu3j3baptfz3r5eoqf2/app.bsky.feed.post/3lhejytgn4c24</td>
#       <td id="T_c01bf_row3_col2" class="data row3 col2" >I like how he’s too bro to tuck in the shirt, just puts the belt around it</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row4_col0" class="data row4 col0" >2025-02-04T17:03:51.591Z</td>
#       <td id="T_c01bf_row4_col1" class="data row4 col1" >at://did:plc:kdfeyljkeezfmbhplhbgnun5/app.bsky.feed.post/3lhejz5j7es2r</td>
#       <td id="T_c01bf_row4_col2" class="data row4 col2" >Good, cuz I never manage to make myself gape so I’m relying on you bro 👀</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row5_col0" class="data row5 col0" >2025-02-04T17:04:00.691Z</td>
#       <td id="T_c01bf_row5_col1" class="data row5 col1" >at://did:plc:tyfbq5qsy34d3s2xz5rptdii/app.bsky.feed.post/3lhejzgh2tk2u</td>
#       <td id="T_c01bf_row5_col2" class="data row5 col2" >Bro skipped every single leg day tryna impress twinks w arm muscle</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row6_col0" class="data row6 col0" >2025-02-04T17:04:00.996Z</td>
#       <td id="T_c01bf_row6_col1" class="data row6 col1" >at://did:plc:jecowr67m4kclijoza5bws4m/app.bsky.feed.post/3lhejzgnzik2h</td>
#       <td id="T_c01bf_row6_col2" class="data row6 col2" >How do you turn off the porn accounts while looking for cute stuff? Goth/hello kitty searches, bro I am not interested in any of that. 🫠 I actually only want to see sanrio and spooky stuff. Not poosee lips and tiddies. 🙃 I wanna see cutie stuff, NOT coochie stuff.</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row7_col0" class="data row7 col0" >2025-02-04T17:04:11.419Z</td>
#       <td id="T_c01bf_row7_col1" class="data row7 col1" >at://did:plc:6comhmbsjsvmzuvgmjzmzwpy/app.bsky.feed.post/3lhejzqmso22e</td>
#       <td id="T_c01bf_row7_col2" class="data row7 col2" >Bro looks like his mom told him “you ain’t leaving until all your chores are done”</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row8_col0" class="data row8 col0" >2025-02-04T17:04:18.820Z</td>
#       <td id="T_c01bf_row8_col1" class="data row8 col1" >at://did:plc:3gxlsgpcwwppj37l2l3ygrpo/app.bsky.feed.post/3lhejzy7yvc2d</td>
#       <td id="T_c01bf_row8_col2" class="data row8 col2" >Disclaimer: I am not a tech bro so miss me with the "bullish on AGI" bullshit or whatever. I just think the openly negative sentiment around anything labeled "AI" has obscured the things going on in AI that seem to be a net positive. & I don't mean this in a defeatist sense, but it's not going away</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row9_col0" class="data row9 col0" >2025-02-04T17:04:23.509Z</td>
#       <td id="T_c01bf_row9_col1" class="data row9 col1" >at://did:plc:u7cf7nkfjf65u6ve4qtulnqq/app.bsky.feed.post/3lhek23qx5k2n</td>
#       <td id="T_c01bf_row9_col2" class="data row9 col2" >me too bro me too</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row10_col0" class="data row10 col0" >2025-02-04T17:04:44.014Z</td>
#       <td id="T_c01bf_row10_col1" class="data row10 col1" >at://did:plc:3m7huebyyoqbltf4bwi6bu33/app.bsky.feed.post/3lhek2pspbs2v</td>
#       <td id="T_c01bf_row10_col2" class="data row10 col2" >bro looks like he is from hueco mundo</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row11_col0" class="data row11 col0" >2025-02-04T17:04:44.195Z</td>
#       <td id="T_c01bf_row11_col1" class="data row11 col1" >at://did:plc:iadxeayos26b6dd2qnydnigs/app.bsky.feed.post/3lhek2q22n22e</td>
#       <td id="T_c01bf_row11_col2" class="data row11 col2" >Bro Merica is falling apart. Take that 5090 and shove it up your arse. May those extra generated frames give you a look at where your head is at.</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row12_col0" class="data row12 col0" >2025-02-04T17:05:10.903Z</td>
#       <td id="T_c01bf_row12_col1" class="data row12 col1" >at://did:plc:sk6zl4vfzxbwu6qdeielbrfj/app.bsky.feed.post/3lhek3hy4ck25</td>
#       <td id="T_c01bf_row12_col2" class="data row12 col2" >bro means ex girlfriend XD</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row13_col0" class="data row13 col0" >2025-02-04T17:05:16.479Z</td>
#       <td id="T_c01bf_row13_col1" class="data row13 col1" >at://did:plc:dfrwtamciw4hthqm34k66vhp/app.bsky.feed.post/3lhek3outrs2o</td>
#       <td id="T_c01bf_row13_col2" class="data row13 col2" >she'll come home soon bro don't sweat it too much</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row14_col0" class="data row14 col0" >2025-02-04T17:06:32.421Z</td>
#       <td id="T_c01bf_row14_col1" class="data row14 col1" >at://did:plc:a55ia2ojiv2cnshifmrc7wr6/app.bsky.feed.post/3lhek5xfw732o</td>
#       <td id="T_c01bf_row14_col2" class="data row14 col2" >Does any of that *matter* if you're having a Red Bull weekend where your goal is to bang out some functions that do a thing with inputs that work the way you assume the inputs work because you haven't spent time getting neck-deep in the messiness of your data? nah, bro 6/</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row15_col0" class="data row15 col0" >2025-02-04T17:06:51.743Z</td>
#       <td id="T_c01bf_row15_col1" class="data row15 col1" >at://did:plc:hj5qebzylzjj5o3kas34sm2n/app.bsky.feed.post/3lhek6k5mms2h</td>
#       <td id="T_c01bf_row15_col2" class="data row15 col2" >Yeah :(((((
#
# Im so sorry hun
#
# Today was a big wtf moment
#
# Fuck that leaker who lied bro
#
# I cannot STAAAAND leakers who just say shit
#
# Like if you dont know then dont say anything
#
# Whole point of a leak is that its true and it was leaked???
#
# Otherwise you just speculating</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row16_col0" class="data row16 col0" >2025-02-04T17:07:25.003Z</td>
#       <td id="T_c01bf_row16_col1" class="data row16 col1" >at://did:plc:hxuleqowvrwstn65ognkflna/app.bsky.feed.post/3lhek7g5ils2c</td>
#       <td id="T_c01bf_row16_col2" class="data row16 col2" >bro what</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row17_col0" class="data row17 col0" >2025-02-04T17:07:41.681Z</td>
#       <td id="T_c01bf_row17_col1" class="data row17 col1" >at://did:plc:4yg7dfkbwby3n4gukmvq4tqn/app.bsky.feed.post/3lhek7zctkc2q</td>
#       <td id="T_c01bf_row17_col2" class="data row17 col2" >ITS TOTALLY NOT PEE BRO ITS DIFFERENT</td>
#     </tr>
#     <tr>
#       <td id="T_c01bf_row18_col0" cl

# %% [markdown]
# ## Prettify the data
# Let's find some ways to make the data a little more presentable. Let's get real URLs, a cleaner timestamp, and highlight the word.

# %%
from src.notebook_helpers import make_link
from src.notebook_helpers import prettify_time
from src.notebook_helpers import mark

# %%
highlight = lambda s: f'{mark(s, "(bro+)")}'

# %%
pretty_data = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)

pretty_data = pretty_data.reset_index(drop=True)

pretty_data.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_470f7">
#   <caption>Showing 851 of 21290 instances of bro</caption>
#   <thead>
#     <tr>
#       <th id="T_470f7_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_470f7_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_470f7_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_470f7_row0_col0" class="data row0 col0" >Feb 04, 2025 05:02PM</td>
#       <td id="T_470f7_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:zljlg7cgdfsl7maqvjjpp7i4/post/3lhejwqzwus2d">Post</a></td>
#       <td id="T_470f7_row0_col2" class="data row0 col2" ><mark>bro</mark> named his dog after william f buckley lmfaoo</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row1_col0" class="data row1 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_470f7_row1_col1" class="data row1 col1" ><a href="https://bsky.app/profile/did:plc:a54rlrqaz5tupdleps5ygd2s/post/3lhejxozykk24">Post</a></td>
#       <td id="T_470f7_row1_col2" class="data row1 col2" >How come I just saw my neighbor put a full trash bag on the hood of his car and drove it to the dumpster that way. Like <mark>bro</mark> was the smell that horrendous you refused to put it in ur car for 500 ft</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row2_col0" class="data row2 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_470f7_row2_col1" class="data row2 col1" ><a href="https://bsky.app/profile/did:plc:tusj3ujtamsxcxj5tfbe4jgd/post/3lhejxrokmc26">Post</a></td>
#       <td id="T_470f7_row2_col2" class="data row2 col2" ><mark>Bro</mark> they aren’t done either 🤣
# They have 29 days to make another deal, and they have to show they actually secure their side.</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row3_col0" class="data row3 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_470f7_row3_col1" class="data row3 col1" ><a href="https://bsky.app/profile/did:plc:ozzimeu3j3baptfz3r5eoqf2/post/3lhejytgn4c24">Post</a></td>
#       <td id="T_470f7_row3_col2" class="data row3 col2" >I like how he’s too <mark>bro</mark> to tuck in the shirt, just puts the belt around it</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row4_col0" class="data row4 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_470f7_row4_col1" class="data row4 col1" ><a href="https://bsky.app/profile/did:plc:kdfeyljkeezfmbhplhbgnun5/post/3lhejz5j7es2r">Post</a></td>
#       <td id="T_470f7_row4_col2" class="data row4 col2" >Good, cuz I never manage to make myself gape so I’m relying on you <mark>bro</mark> 👀</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row5_col0" class="data row5 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row5_col1" class="data row5 col1" ><a href="https://bsky.app/profile/did:plc:tyfbq5qsy34d3s2xz5rptdii/post/3lhejzgh2tk2u">Post</a></td>
#       <td id="T_470f7_row5_col2" class="data row5 col2" ><mark>Bro</mark> skipped every single leg day tryna impress twinks w arm muscle</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row6_col0" class="data row6 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row6_col1" class="data row6 col1" ><a href="https://bsky.app/profile/did:plc:jecowr67m4kclijoza5bws4m/post/3lhejzgnzik2h">Post</a></td>
#       <td id="T_470f7_row6_col2" class="data row6 col2" >How do you turn off the porn accounts while looking for cute stuff? Goth/hello kitty searches, <mark>bro</mark> I am not interested in any of that. 🫠 I actually only want to see sanrio and spooky stuff. Not poosee lips and tiddies. 🙃 I wanna see cutie stuff, NOT coochie stuff.</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row7_col0" class="data row7 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row7_col1" class="data row7 col1" ><a href="https://bsky.app/profile/did:plc:6comhmbsjsvmzuvgmjzmzwpy/post/3lhejzqmso22e">Post</a></td>
#       <td id="T_470f7_row7_col2" class="data row7 col2" ><mark>Bro</mark> looks like his mom told him “you ain’t leaving until all your chores are done”</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row8_col0" class="data row8 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row8_col1" class="data row8 col1" ><a href="https://bsky.app/profile/did:plc:3gxlsgpcwwppj37l2l3ygrpo/post/3lhejzy7yvc2d">Post</a></td>
#       <td id="T_470f7_row8_col2" class="data row8 col2" >Disclaimer: I am not a tech <mark>bro</mark> so miss me with the &#34;bullish on AGI&#34; bullshit or whatever. I just think the openly negative sentiment around anything labeled &#34;AI&#34; has obscured the things going on in AI that seem to be a net positive. &amp; I don&#39;t mean this in a defeatist sense, but it&#39;s not going away</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row9_col0" class="data row9 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row9_col1" class="data row9 col1" ><a href="https://bsky.app/profile/did:plc:u7cf7nkfjf65u6ve4qtulnqq/post/3lhek23qx5k2n">Post</a></td>
#       <td id="T_470f7_row9_col2" class="data row9 col2" >me too <mark>bro</mark> me too</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row10_col0" class="data row10 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row10_col1" class="data row10 col1" ><a href="https://bsky.app/profile/did:plc:3m7huebyyoqbltf4bwi6bu33/post/3lhek2pspbs2v">Post</a></td>
#       <td id="T_470f7_row10_col2" class="data row10 col2" ><mark>bro</mark> looks like he is from hueco mundo</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row11_col0" class="data row11 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_470f7_row11_col1" class="data row11 col1" ><a href="https://bsky.app/profile/did:plc:iadxeayos26b6dd2qnydnigs/post/3lhek2q22n22e">Post</a></td>
#       <td id="T_470f7_row11_col2" class="data row11 col2" ><mark>Bro</mark> Merica is falling apart. Take that 5090 and shove it up your arse. May those extra generated frames give you a look at where your head is at.</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row12_col0" class="data row12 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_470f7_row12_col1" class="data row12 col1" ><a href="https://bsky.app/profile/did:plc:sk6zl4vfzxbwu6qdeielbrfj/post/3lhek3hy4ck25">Post</a></td>
#       <td id="T_470f7_row12_col2" class="data row12 col2" ><mark>bro</mark> means ex girlfriend XD</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row13_col0" class="data row13 col0" >Feb 04, 2025 05:05PM</td>
#       <td id="T_470f7_row13_col1" class="data row13 col1" ><a href="https://bsky.app/profile/did:plc:dfrwtamciw4hthqm34k66vhp/post/3lhek3outrs2o">Post</a></td>
#       <td id="T_470f7_row13_col2" class="data row13 col2" >she&#39;ll come home soon <mark>bro</mark> don&#39;t sweat it too much</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row14_col0" class="data row14 col0" >Feb 04, 2025 05:06PM</td>
#       <td id="T_470f7_row14_col1" class="data row14 col1" ><a href="https://bsky.app/profile/did:plc:a55ia2ojiv2cnshifmrc7wr6/post/3lhek5xfw732o">Post</a></td>
#       <td id="T_470f7_row14_col2" class="data row14 col2" >Does any of that *matter* if you&#39;re having a Red Bull weekend where your goal is to bang out some functions that do a thing with inputs that work the way you assume the inputs work because you haven&#39;t spent time getting neck-deep in the messiness of your data? nah, <mark>bro</mark> 6/</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row15_col0" class="data row15 col0" >Feb 04, 2025 05:06PM</td>
#       <td id="T_470f7_row15_col1" class="data row15 col1" ><a href="https://bsky.app/profile/did:plc:hj5qebzylzjj5o3kas34sm2n/post/3lhek6k5mms2h">Post</a></td>
#       <td id="T_470f7_row15_col2" class="data row15 col2" >Yeah :(((((
#
# Im so sorry hun
#
# Today was a big wtf moment
#
# Fuck that leaker who lied <mark>bro</mark>
#
# I cannot STAAAAND leakers who just say shit
#
# Like if you dont know then dont say anything
#
# Whole point of a leak is that its true and it was leaked???
#
# Otherwise you just speculating</td>
#     </tr>
#     <tr>
#       <td id="T_470f7_row16_col0" class="data row16 col0" >Feb 04, 2025 05:07PM</td>
#       <

# %% [markdown]
# ## What about the Pejorative Bro?
# Pejorative Bro is identified  as being a bro of the type:
#
# * tech
# * finance
# * gym
# * crypto
# * ai
#
# Or a `[word]-bro`

# %%
bro_mods = ['tech','crypto', 'gym', 'finance', 'douche', 'ai', 'musk', 'art', 'debate']
pejorative_regex = re.compile(f'((?:{"|".join(bro_mods)})(?:\\s|-)?bros?)|\\w+-bros?')
pejorative_rows = [row for row in pronoun_rows if pejorative_regex.search(row[2])]
pejorative_highlight = lambda s: f'{mark(s, f'(((?:{"|".join(bro_mods)})(?:\\s|-)?bros?)|\\w+-bros?)')}'

pejorative_bro_rows = {} #for inspection if needed

for mod in bro_mods:
    mod_regex = re.compile(f"({mod}(?:\\s|-)?bros?)")
    rows = [row for row in pejorative_rows if mod_regex.search(row[2])]
    pejorative_bro_rows[mod] = rows

pejorative_bro_counts = {k:len(v) for k,v in zip(pejorative_bro_rows.keys(), pejorative_bro_rows.values())}
total_pbr = len(pejorative_rows)
pbr_data = {'Modifier': pejorative_bro_counts.keys(), 'Count': pejorative_bro_counts.values()}
pmd = pd.DataFrame(pbr_data)
pmd['Percent'] = (pmd['Count'] / pmd['Count'].sum()) * 100
pmd.style\
    .hide(axis="index")\
    .set_caption(f"Occurences of Pejorative Bro out of {total_pbr} total instances")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4028">
#   <caption>Occurences of Pejorative Bro out of 1628 total instances</caption>
#   <thead>
#     <tr>
#       <th id="T_b4028_level0_col0" class="col_heading level0 col0" >Modifier</th>
#       <th id="T_b4028_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_b4028_level0_col2" class="col_heading level0 col2" >Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4028_row0_col0" class="data row0 col0" >tech</td>
#       <td id="T_b4028_row0_col1" class="data row0 col1" >1326</td>
#       <td id="T_b4028_row0_col2" class="data row0 col2" >82.719900</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row1_col0" class="data row1 col0" >crypto</td>
#       <td id="T_b4028_row1_col1" class="data row1 col1" >115</td>
#       <td id="T_b4028_row1_col2" class="data row1 col2" >7.174049</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row2_col0" class="data row2 col0" >gym</td>
#       <td id="T_b4028_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_b4028_row2_col2" class="data row2 col2" >3.680599</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row3_col0" class="data row3 col0" >finance</td>
#       <td id="T_b4028_row3_col1" class="data row3 col1" >37</td>
#       <td id="T_b4028_row3_col2" class="data row3 col2" >2.308172</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row4_col0" class="data row4 col0" >douche</td>
#       <td id="T_b4028_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_b4028_row4_col2" class="data row4 col2" >0.810979</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row5_col0" class="data row5 col0" >ai</td>
#       <td id="T_b4028_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_b4028_row5_col2" class="data row5 col2" >0.561447</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row6_col0" class="data row6 col0" >musk</td>
#       <td id="T_b4028_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_b4028_row6_col2" class="data row6 col2" >0.249532</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row7_col0" class="data row7 col0" >art</td>
#       <td id="T_b4028_row7_col1" class="data row7 col1" >13</td>
#       <td id="T_b4028_row7_col2" class="data row7 col2" >0.810979</td>
#     </tr>
#     <tr>
#       <td id="T_b4028_row8_col0" class="data row8 col0" >debate</td>
#       <td id="T_b4028_row8_col1" class="data row8 col1" >27</td>
#       <td id="T_b4028_row8_col2" class="data row8 col2" >1.684342</td>
#     </tr>
#   </tbody>
# </table>

# %%
pretty_pej_data = pd.DataFrame(pejorative_rows, columns=column_titles)
pretty_pej_data = pretty_pej_data.reset_index(drop=True)
pretty_pej_data.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=pejorative_highlight, escape='html' )\
    .set_caption(f"Showing {total_pbr} instances of {"|".join(bro_mods)} {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7bc2">
#   <caption>Showing 1628 instances of tech|crypto|gym|finance|douche|ai|musk|art|debate bro</caption>
#   <thead>
#     <tr>
#       <th id="T_e7bc2_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_e7bc2_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_e7bc2_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7bc2_row0_col0" class="data row0 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e7bc2_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:3gxlsgpcwwppj37l2l3ygrpo/post/3lhejzy7yvc2d">Post</a></td>
#       <td id="T_e7bc2_row0_col2" class="data row0 col2" >Disclaimer: I am not a <mark>tech bro</mark> so miss me with the &#34;bullish on AGI&#34; bullshit or whatever. I just think the openly negative sentiment around anything labeled &#34;AI&#34; has obscured the things going on in AI that seem to be a net positive. &amp; I don&#39;t mean this in a defeatist sense, but it&#39;s not going away</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row1_col0" class="data row1 col0" >Feb 04, 2025 05:08PM</td>
#       <td id="T_e7bc2_row1_col1" class="data row1 col1" ><a href="https://bsky.app/profile/did:plc:a7fvaj4o36ircda7bsjlrkjv/post/3lhekbwy52k2c">Post</a></td>
#       <td id="T_e7bc2_row1_col2" class="data row1 col2" >Yep. Very well could be. Young <mark>tech bro</mark> boys and gay billionaire in the same sentence tracks.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row2_col0" class="data row2 col0" >Feb 04, 2025 05:11PM</td>
#       <td id="T_e7bc2_row2_col1" class="data row2 col1" ><a href="https://bsky.app/profile/did:plc:6ow563xyhjp34ka27de4zlli/post/3lhekgeonkc2r">Post</a></td>
#       <td id="T_e7bc2_row2_col2" class="data row2 col2" >OMG - <mark>tech bro</mark> crypto numbers...SMDH...</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row3_col0" class="data row3 col0" >Feb 04, 2025 05:15PM</td>
#       <td id="T_e7bc2_row3_col1" class="data row3 col1" ><a href="https://bsky.app/profile/did:plc:yfysfxoluuc4trcjva67i3vk/post/3lhekni4oz22n">Post</a></td>
#       <td id="T_e7bc2_row3_col2" class="data row3 col2" >I know them. They’re in a cult-the <mark>tech bro</mark> algorithm got to them. Not allowed to talk about anything real with them-total meltdown/full diaper energy.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row4_col0" class="data row4 col0" >Feb 04, 2025 05:19PM</td>
#       <td id="T_e7bc2_row4_col1" class="data row4 col1" ><a href="https://bsky.app/profile/did:plc:3rdyvhvdogv4dinnuc3jnel5/post/3lhekvbafqc2c">Post</a></td>
#       <td id="T_e7bc2_row4_col2" class="data row4 col2" >Arrest, detain and charge Elon musk and his <mark>tech bro</mark> Bros with seditious conspiracy to defraud the American taxpayers and overthrow our government of the United States of America! Do it now while we still can.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row5_col0" class="data row5 col0" >Feb 04, 2025 05:28PM</td>
#       <td id="T_e7bc2_row5_col1" class="data row5 col1" ><a href="https://bsky.app/profile/did:plc:6pkdziukpu4fgo3nbqranzau/post/3lheledlse22w">Post</a></td>
#       <td id="T_e7bc2_row5_col2" class="data row5 col2" >Not a big surprise that vengeful Donnie&#39;s <mark>first-bro</mark> is also a vindictive asshole</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row6_col0" class="data row6 col0" >Feb 04, 2025 05:28PM</td>
#       <td id="T_e7bc2_row6_col1" class="data row6 col1" ><a href="https://bsky.app/profile/did:plc:mqtzzoxzs32s3ojxwsha3ljd/post/3lhelfajs6s2o">Post</a></td>
#       <td id="T_e7bc2_row6_col2" class="data row6 col2" >And him using his daddy’s money and dumb <mark>tech bro</mark> VC (buying his first useless company) to buy other people’s ideas and pretend they were his.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row7_col0" class="data row7 col0" >Feb 04, 2025 05:29PM</td>
#       <td id="T_e7bc2_row7_col1" class="data row7 col1" ><a href="https://bsky.app/profile/did:plc:3rdyvhvdogv4dinnuc3jnel5/post/3lhelh7dcus2c">Post</a></td>
#       <td id="T_e7bc2_row7_col2" class="data row7 col2" >Musk and his <mark>tech bro</mark> Bros need to be arrested and charged with seditious conspiracy to defraud the American taxpayers. Not to mention over throw our government of the United States.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row8_col0" class="data row8 col0" >Feb 04, 2025 05:33PM</td>
#       <td id="T_e7bc2_row8_col1" class="data row8 col1" ><a href="https://bsky.app/profile/did:plc:3rdyvhvdogv4dinnuc3jnel5/post/3lhelo46r3c2c">Post</a></td>
#       <td id="T_e7bc2_row8_col2" class="data row8 col2" >Arrest, detain and charge Elon musk and his <mark>tech bro</mark> Bros with seditious conspiracy to defraud American taxpayers by illegally capturing our Treasury payment system. Which by consequence is seditious conspiracy to overthrow our government of the United States of America.
# How about them apples?</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row9_col0" class="data row9 col0" >Feb 04, 2025 05:34PM</td>
#       <td id="T_e7bc2_row9_col1" class="data row9 col1" ><a href="https://bsky.app/profile/did:plc:nj7iog6v4yov2e7tctmwq6n3/post/3lhelqaqm7c2i">Post</a></td>
#       <td id="T_e7bc2_row9_col2" class="data row9 col2" >They are trying to create a new <mark>tech bro</mark> city near Travis Air Force Base, and I am not sure they won&#39;t succeed to some extent.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row10_col0" class="data row10 col0" >Feb 04, 2025 05:37PM</td>
#       <td id="T_e7bc2_row10_col1" class="data row10 col1" ><a href="https://bsky.app/profile/did:plc:3rdyvhvdogv4dinnuc3jnel5/post/3lhelupq5722c">Post</a></td>
#       <td id="T_e7bc2_row10_col2" class="data row10 col2" >Arrest, detain and charge the foreigner Elon musk and his <mark>tech bro</mark> Bros with seditious conspiracy to defraud American taxpayers by taking control of our US Treasury system. And thereby seditious conspiracy to overthrow our government of the United States of America!
# Lock him up. And no internet!!!</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row11_col0" class="data row11 col0" >Feb 04, 2025 05:39PM</td>
#       <td id="T_e7bc2_row11_col1" class="data row11 col1" ><a href="https://bsky.app/profile/did:plc:zfndpaogevfmvu67wdmjul2f/post/3lhelzlhjx22j">Post</a></td>
#       <td id="T_e7bc2_row11_col2" class="data row11 col2" >Junior <mark>tech bro</mark> kids granted access to USG systems and sensitive information on US citizens. National security event waiting to happen… I’m sure our adversaries are licking their chops.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row12_col0" class="data row12 col0" >Feb 04, 2025 05:45PM</td>
#       <td id="T_e7bc2_row12_col1" class="data row12 col1" ><a href="https://bsky.app/profile/did:plc:ddgqgqbohcippbunnnjgvdpj/post/3lhemd7ant22z">Post</a></td>
#       <td id="T_e7bc2_row12_col2" class="data row12 col2" >You&#39;re absolutely correct. I&#39;m mad about the current state of things, yes—but I&#39;m almost more angry that we&#39;re being tyrannized by a bunch of <mark>tech bro</mark> losers 🙏🏻😭 These were not the &#39;villains&#39; that the comics promised us.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row13_col0" class="data row13 col0" >Feb 04, 2025 05:52PM</td>
#       <td id="T_e7bc2_row13_col1" class="data row13 col1" ><a href="https://bsky.app/profile/did:plc:d6gfmwqotkciuavbft576tvz/post/3lhemqpbs4k2p">Post</a></td>
#       <td id="T_e7bc2_row13_col2" class="data row13 col2" >If you receive your paycheck &amp; reimbursements via EFT - Elon Musk and the <mark>tech bro</mark> babies have YOUR bank account and routing information along with your other personal data.
#
# There&#39;s allegations he made copies onto his own harddrives.</td>
#     </tr>
#     <tr>
#       <td id="T_e7bc2_row14_col0" class="data row14 col0" >Feb 04, 2025 06:00PM</td>
#       <td id="T_e7bc2_row14_col1" class="data row14 col1" ><a href="https://bsky.app/profile/did:plc:d6gfmwqotkc

# %% [markdown]
# ## Now let's look at some sentiment

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
rows_with_sentiment = []
column_titles = ['Time', 'URI', 'Post Text', 'Negative', 'Neutral', 'Positive', 'Compound']

neg_count = 0
pos_count = 0
neu_count = 0
for row in pronoun_rows:
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(row[2])
    row_as_list = list(row)
    row_as_list.append(ss['neg'])
    neg_count += ss['neg']
    row_as_list.append(ss['neu'])
    neu_count += ss['neu']
    row_as_list.append(ss['pos'])
    pos_count += ss['pos']
    row_as_list.append(ss['compound'])
    rows_with_sentiment.append(row_as_list)



pretty_sentiment = pd.DataFrame(rows_with_sentiment[0:raw_slice_size], columns=column_titles)

ps = pretty_sentiment.reset_index(drop=True)

ps.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4f86">
#   <caption>Showing 851 of 21290 instances of bro</caption>
#   <thead>
#     <tr>
#       <th id="T_e4f86_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_e4f86_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_e4f86_level0_col2" class="col_heading level0 col2" >Post Text</th>
#       <th id="T_e4f86_level0_col3" class="col_heading level0 col3" >Negative</th>
#       <th id="T_e4f86_level0_col4" class="col_heading level0 col4" >Neutral</th>
#       <th id="T_e4f86_level0_col5" class="col_heading level0 col5" >Positive</th>
#       <th id="T_e4f86_level0_col6" class="col_heading level0 col6" >Compound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e4f86_row0_col0" class="data row0 col0" >Feb 04, 2025 05:02PM</td>
#       <td id="T_e4f86_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:zljlg7cgdfsl7maqvjjpp7i4/post/3lhejwqzwus2d">Post</a></td>
#       <td id="T_e4f86_row0_col2" class="data row0 col2" ><mark>bro</mark> named his dog after william f buckley lmfaoo</td>
#       <td id="T_e4f86_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_e4f86_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_e4f86_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_e4f86_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row1_col0" class="data row1 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_e4f86_row1_col1" class="data row1 col1" ><a href="https://bsky.app/profile/did:plc:a54rlrqaz5tupdleps5ygd2s/post/3lhejxozykk24">Post</a></td>
#       <td id="T_e4f86_row1_col2" class="data row1 col2" >How come I just saw my neighbor put a full trash bag on the hood of his car and drove it to the dumpster that way. Like <mark>bro</mark> was the smell that horrendous you refused to put it in ur car for 500 ft</td>
#       <td id="T_e4f86_row1_col3" class="data row1 col3" >0.158000</td>
#       <td id="T_e4f86_row1_col4" class="data row1 col4" >0.790000</td>
#       <td id="T_e4f86_row1_col5" class="data row1 col5" >0.052000</td>
#       <td id="T_e4f86_row1_col6" class="data row1 col6" >-0.624900</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row2_col0" class="data row2 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_e4f86_row2_col1" class="data row2 col1" ><a href="https://bsky.app/profile/did:plc:tusj3ujtamsxcxj5tfbe4jgd/post/3lhejxrokmc26">Post</a></td>
#       <td id="T_e4f86_row2_col2" class="data row2 col2" ><mark>Bro</mark> they aren’t done either 🤣
# They have 29 days to make another deal, and they have to show they actually secure their side.</td>
#       <td id="T_e4f86_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_e4f86_row2_col4" class="data row2 col4" >0.902000</td>
#       <td id="T_e4f86_row2_col5" class="data row2 col5" >0.098000</td>
#       <td id="T_e4f86_row2_col6" class="data row2 col6" >0.340000</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row3_col0" class="data row3 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_e4f86_row3_col1" class="data row3 col1" ><a href="https://bsky.app/profile/did:plc:ozzimeu3j3baptfz3r5eoqf2/post/3lhejytgn4c24">Post</a></td>
#       <td id="T_e4f86_row3_col2" class="data row3 col2" >I like how he’s too <mark>bro</mark> to tuck in the shirt, just puts the belt around it</td>
#       <td id="T_e4f86_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_e4f86_row3_col4" class="data row3 col4" >0.857000</td>
#       <td id="T_e4f86_row3_col5" class="data row3 col5" >0.143000</td>
#       <td id="T_e4f86_row3_col6" class="data row3 col6" >0.361200</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row4_col0" class="data row4 col0" >Feb 04, 2025 05:03PM</td>
#       <td id="T_e4f86_row4_col1" class="data row4 col1" ><a href="https://bsky.app/profile/did:plc:kdfeyljkeezfmbhplhbgnun5/post/3lhejz5j7es2r">Post</a></td>
#       <td id="T_e4f86_row4_col2" class="data row4 col2" >Good, cuz I never manage to make myself gape so I’m relying on you <mark>bro</mark> 👀</td>
#       <td id="T_e4f86_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_e4f86_row4_col4" class="data row4 col4" >0.818000</td>
#       <td id="T_e4f86_row4_col5" class="data row4 col5" >0.182000</td>
#       <td id="T_e4f86_row4_col6" class="data row4 col6" >0.440400</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row5_col0" class="data row5 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e4f86_row5_col1" class="data row5 col1" ><a href="https://bsky.app/profile/did:plc:tyfbq5qsy34d3s2xz5rptdii/post/3lhejzgh2tk2u">Post</a></td>
#       <td id="T_e4f86_row5_col2" class="data row5 col2" ><mark>Bro</mark> skipped every single leg day tryna impress twinks w arm muscle</td>
#       <td id="T_e4f86_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_e4f86_row5_col4" class="data row5 col4" >0.775000</td>
#       <td id="T_e4f86_row5_col5" class="data row5 col5" >0.225000</td>
#       <td id="T_e4f86_row5_col6" class="data row5 col6" >0.440400</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row6_col0" class="data row6 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e4f86_row6_col1" class="data row6 col1" ><a href="https://bsky.app/profile/did:plc:jecowr67m4kclijoza5bws4m/post/3lhejzgnzik2h">Post</a></td>
#       <td id="T_e4f86_row6_col2" class="data row6 col2" >How do you turn off the porn accounts while looking for cute stuff? Goth/hello kitty searches, <mark>bro</mark> I am not interested in any of that. 🫠 I actually only want to see sanrio and spooky stuff. Not poosee lips and tiddies. 🙃 I wanna see cutie stuff, NOT coochie stuff.</td>
#       <td id="T_e4f86_row6_col3" class="data row6 col3" >0.045000</td>
#       <td id="T_e4f86_row6_col4" class="data row6 col4" >0.819000</td>
#       <td id="T_e4f86_row6_col5" class="data row6 col5" >0.136000</td>
#       <td id="T_e4f86_row6_col6" class="data row6 col6" >0.548700</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row7_col0" class="data row7 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e4f86_row7_col1" class="data row7 col1" ><a href="https://bsky.app/profile/did:plc:6comhmbsjsvmzuvgmjzmzwpy/post/3lhejzqmso22e">Post</a></td>
#       <td id="T_e4f86_row7_col2" class="data row7 col2" ><mark>Bro</mark> looks like his mom told him “you ain’t leaving until all your chores are done”</td>
#       <td id="T_e4f86_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_e4f86_row7_col4" class="data row7 col4" >0.857000</td>
#       <td id="T_e4f86_row7_col5" class="data row7 col5" >0.143000</td>
#       <td id="T_e4f86_row7_col6" class="data row7 col6" >0.361200</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row8_col0" class="data row8 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e4f86_row8_col1" class="data row8 col1" ><a href="https://bsky.app/profile/did:plc:3gxlsgpcwwppj37l2l3ygrpo/post/3lhejzy7yvc2d">Post</a></td>
#       <td id="T_e4f86_row8_col2" class="data row8 col2" >Disclaimer: I am not a tech <mark>bro</mark> so miss me with the &#34;bullish on AGI&#34; bullshit or whatever. I just think the openly negative sentiment around anything labeled &#34;AI&#34; has obscured the things going on in AI that seem to be a net positive. &amp; I don&#39;t mean this in a defeatist sense, but it&#39;s not going away</td>
#       <td id="T_e4f86_row8_col3" class="data row8 col3" >0.144000</td>
#       <td id="T_e4f86_row8_col4" class="data row8 col4" >0.815000</td>
#       <td id="T_e4f86_row8_col5" class="data row8 col5" >0.041000</td>
#       <td id="T_e4f86_row8_col6" class="data row8 col6" >-0.593800</td>
#     </tr>
#     <tr>
#       <td id="T_e4f86_row9_col0" class="data row9 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_e4f86_row9_col1" class="data row9 col1" ><a href="https://bsky.app/profile/did:plc:u7cf7nkfjf65u6ve4qtulnqq/post/3lhek23qx5k2n">Post</a></td>
#       <td id="T_e4f86_row9_col2" class="data row9 col2" >me too <mark>bro</mark> me too</td>
#       <td id="T_e4f86_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_e4f86_r

# %%
mean_neg = neg_count / len(pronoun_rows)
mean_pos = pos_count / len(pronoun_rows)
mean_neu = neu_count / len(pronoun_rows)

print(f"""
Mean Negative Sentiment {mean_neg}
Mean Positive Sentiment {mean_pos}
Mean Neutral Sentiment {mean_neu}
""")
# Out:
# Mean Negative Sentiment 0.10793100046970425
# Mean Positive Sentiment 0.11620070455612957
# Mean Neutral Sentiment 0.7758673555659956

# %% [markdown]
# ## Now some other useful information from context

# %%
from src.notebook_helpers import get_frequency_dict, get_instance_dict
from src.regexes import PROFANITY_REGEX
from src.regexes import AFFIRMATION_REGEX
from src.regexes import NEGATION_REGEX
from src.regexes import EMOJI_REGEX

# %%
negations = get_frequency_dict(pronoun_rows, NEGATION_REGEX)
affirmations = get_frequency_dict(pronoun_rows, AFFIRMATION_REGEX)
profanities = get_frequency_dict(pronoun_rows, PROFANITY_REGEX)
emojis = get_frequency_dict(pronoun_rows, EMOJI_REGEX)

# %%
total_negations = sum( v for k,v in negations.items() )
total_affirmations =  sum( v for k,v in affirmations.items() )
total_profanities = sum( v for k,v in affirmations.items() )
total_emojis = sum(v for k,v in emojis.items() )

# %%
negation_density = get_instance_dict(negations.keys(), pronoun_rows)
total_neg_posts = sum( v for k,v in negation_density.items() )
neg_table = pd.DataFrame(negations.items(), columns=['Negation', 'Total Occurences'])
neg_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
nt = neg_table.reset_index(drop=True)

nt['Posts with One'] = nt['Negation'].map(negation_density)
nt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_negations} negations from {total_neg_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b2324">
#   <caption>Showing 1282 negations from 1193 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_b2324_level0_col0" class="col_heading level0 col0" >Negation</th>
#       <th id="T_b2324_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_b2324_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b2324_row0_col0" class="data row0 col0" >no</td>
#       <td id="T_b2324_row0_col1" class="data row0 col1" >1069</td>
#       <td id="T_b2324_row0_col2" class="data row0 col2" >982</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row1_col0" class="data row1 col0" >nah</td>
#       <td id="T_b2324_row1_col1" class="data row1 col1" >132</td>
#       <td id="T_b2324_row1_col2" class="data row1 col2" >130</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row2_col0" class="data row2 col0" >nope</td>
#       <td id="T_b2324_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_b2324_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row3_col0" class="data row3 col0" >na</td>
#       <td id="T_b2324_row3_col1" class="data row3 col1" >11</td>
#       <td id="T_b2324_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row4_col0" class="data row4 col0" >naw</td>
#       <td id="T_b2324_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_b2324_row4_col2" class="data row4 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row5_col0" class="data row5 col0" >nooo</td>
#       <td id="T_b2324_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_b2324_row5_col2" class="data row5 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row6_col0" class="data row6 col0" >nooooo</td>
#       <td id="T_b2324_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_b2324_row6_col2" class="data row6 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row7_col0" class="data row7 col0" >noooo</td>
#       <td id="T_b2324_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_b2324_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row8_col0" class="data row8 col0" >noooooooo</td>
#       <td id="T_b2324_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_b2324_row8_col2" class="data row8 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row9_col0" class="data row9 col0" >nuh</td>
#       <td id="T_b2324_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_b2324_row9_col2" class="data row9 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row10_col0" class="data row10 col0" >nooooooooo</td>
#       <td id="T_b2324_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_b2324_row10_col2" class="data row10 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row11_col0" class="data row11 col0" >noooooo</td>
#       <td id="T_b2324_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_b2324_row11_col2" class="data row11 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row12_col0" class="data row12 col0" >naaah</td>
#       <td id="T_b2324_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_b2324_row12_col2" class="data row12 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row13_col0" class="data row13 col0" >noooooooooooooooo</td>
#       <td id="T_b2324_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_b2324_row13_col2" class="data row13 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row14_col0" class="data row14 col0" >nooooooo</td>
#       <td id="T_b2324_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_b2324_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row15_col0" class="data row15 col0" >noooooooooooooo</td>
#       <td id="T_b2324_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_b2324_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row16_col0" class="data row16 col0" >noooooooooooooooooooooo</td>
#       <td id="T_b2324_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_b2324_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row17_col0" class="data row17 col0" >noo</td>
#       <td id="T_b2324_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_b2324_row17_col2" class="data row17 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row18_col0" class="data row18 col0" >naaaaah</td>
#       <td id="T_b2324_row18_col1" class="data row18 col1" >1</td>
#       <td id="T_b2324_row18_col2" class="data row18 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b2324_row19_col0" class="data row19 col0" >noooooooooooooooooo</td>
#       <td id="T_b2324_row19_col1" class="data row19 col1" >1</td>
#       <td id="T_b2324_row19_col2" class="data row19 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
aff_density = get_instance_dict(affirmations.keys(), pronoun_rows)
total_aff_posts = sum( v for k,v in aff_density.items() )

aff_table = pd.DataFrame(affirmations.items(), columns=['Affirmation', 'Total Occurences'])
aff_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

at = aff_table.reset_index(drop=True)
at['Posts with One'] = at['Affirmation'].map(aff_density)

at.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_affirmations} affirmations from {total_aff_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f3a5">
#   <caption>Showing 800 affirmations from 773 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_2f3a5_level0_col0" class="col_heading level0 col0" >Affirmation</th>
#       <th id="T_2f3a5_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_2f3a5_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2f3a5_row0_col0" class="data row0 col0" >yeah</td>
#       <td id="T_2f3a5_row0_col1" class="data row0 col1" >404</td>
#       <td id="T_2f3a5_row0_col2" class="data row0 col2" >393</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row1_col0" class="data row1 col0" >yes</td>
#       <td id="T_2f3a5_row1_col1" class="data row1 col1" >178</td>
#       <td id="T_2f3a5_row1_col2" class="data row1 col2" >175</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row2_col0" class="data row2 col0" >ya</td>
#       <td id="T_2f3a5_row2_col1" class="data row2 col1" >97</td>
#       <td id="T_2f3a5_row2_col2" class="data row2 col2" >88</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row3_col0" class="data row3 col0" >yea</td>
#       <td id="T_2f3a5_row3_col1" class="data row3 col1" >47</td>
#       <td id="T_2f3a5_row3_col2" class="data row3 col2" >47</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row4_col0" class="data row4 col0" >yep</td>
#       <td id="T_2f3a5_row4_col1" class="data row4 col1" >15</td>
#       <td id="T_2f3a5_row4_col2" class="data row4 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row5_col0" class="data row5 col0" >yap</td>
#       <td id="T_2f3a5_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_2f3a5_row5_col2" class="data row5 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row6_col0" class="data row6 col0" >yup</td>
#       <td id="T_2f3a5_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_2f3a5_row6_col2" class="data row6 col2" >11</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row7_col0" class="data row7 col0" >yu</td>
#       <td id="T_2f3a5_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_2f3a5_row7_col2" class="data row7 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row8_col0" class="data row8 col0" >yay</td>
#       <td id="T_2f3a5_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_2f3a5_row8_col2" class="data row8 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row9_col0" class="data row9 col0" >ye</td>
#       <td id="T_2f3a5_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_2f3a5_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row10_col0" class="data row10 col0" >yah</td>
#       <td id="T_2f3a5_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_2f3a5_row10_col2" class="data row10 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row11_col0" class="data row11 col0" >yee</td>
#       <td id="T_2f3a5_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_2f3a5_row11_col2" class="data row11 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row12_col0" class="data row12 col0" >yuh</td>
#       <td id="T_2f3a5_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_2f3a5_row12_col2" class="data row12 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row13_col0" class="data row13 col0" >yeh</td>
#       <td id="T_2f3a5_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_2f3a5_row13_col2" class="data row13 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row14_col0" class="data row14 col0" >yeaaaaa</td>
#       <td id="T_2f3a5_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_2f3a5_row14_col2" class="data row14 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row15_col0" class="data row15 col0" >yey</td>
#       <td id="T_2f3a5_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_2f3a5_row15_col2" class="data row15 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row16_col0" class="data row16 col0" >yeeee</td>
#       <td id="T_2f3a5_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_2f3a5_row16_col2" class="data row16 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row17_col0" class="data row17 col0" >yaaay</td>
#       <td id="T_2f3a5_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_2f3a5_row17_col2" class="data row17 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row18_col0" class="data row18 col0" >yaaaaa</td>
#       <td id="T_2f3a5_row18_col1" class="data row18 col1" >1</td>
#       <td id="T_2f3a5_row18_col2" class="data row18 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2f3a5_row19_col0" class="data row19 col0" >yuuuuup</td>
#       <td id="T_2f3a5_row19_col1" class="data row19 col1" >1</td>
#       <td id="T_2f3a5_row19_col2" class="data row19 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
prof_density = get_instance_dict(profanities.keys(), pronoun_rows)
total_prof_posts = sum( v for k,v in prof_density.items() )

prof_table = pd.DataFrame(profanities.items(), columns=['Profanity', 'Total Occurences'])
prof_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

pt = prof_table.reset_index(drop=True)
pt['Posts with One'] = pt['Profanity'].map(prof_density)

pt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_profanities} profanities from {total_prof_posts} posts using {pronoun}")

# %%
e_density = get_instance_dict(emojis.keys(), pronoun_rows)
total_e_posts = sum( v for k,v in aff_density.items() )

emoji_table = pd.DataFrame(emojis.items(), columns=['Emoji', 'Total Occurences'])
emoji_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
et = emoji_table.reset_index(drop=True)
et['Posts with One'] = et['Emoji'].map(e_density)

et.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_negations} emojis from {total_e_posts} posts using {pronoun}")

# %% [markdown]
# ## Associated Pronouns

# %%
from nltk.tokenize import word_tokenize
from collections import Counter


associate_pronouns = Counter()
for row in pronoun_rows:
    text = row[2]
    tokens = word_tokenize(text)
    poss = nltk.pos_tag(tokens)
    for pos in poss:
        tok,p = pos
        if p == 'PRP$':
            associate_pronouns.update([tok.lower()])

total_pronouns = sum( v for k,v in associate_pronouns.items() )
p_density = get_instance_dict(associate_pronouns.keys(), pronoun_rows)

pron_table = pd.DataFrame(associate_pronouns.items(), columns=['Pronoun', 'Total Occurences'])
pron_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)


pt = pron_table.reset_index(drop=True)
pt['Posts with One'] = pt['Pronoun'].map(p_density)

pt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_pronouns} pronouns that were used with {pronoun}")
