# %% [markdown]
# # Bro Analysis
#
# This is a file for analyzing the use of "bronouns" from a SQL database

# %% [markdown]
# ## Setup

# %%
# dependencies
import sqlite3
import math
import re
import nltk
import pandas as pd
from datetime import datetime

# %%
# Initialize DB
# download a DB from https://osf.io/qfdtn/files/osfstorage
connection = sqlite3.connect('../db.pronouns.with-data.sqlite')
cursor = connection.cursor()

# %%
# Get the Rows
# We care about one table in the DB: post
# The databases may have more or less fields in the posts table. 
# they'll always have indexedAt, uri, text

# Make columns and pronoun variables, so this is reusable
sql_columns = ['indexedAt','uri', 'text']
column_titles = ['Time', 'URI', 'Post Text'] # This is for Pandas, later down
pronoun = 'bro' # Change this to pick a different pronoun. Options: dude, bro, bruh, chat, sis, fam
select_query = f"SELECT {','.join(sql_columns)} FROM post WHERE post.pronoun == '{pronoun}'"
cursor.execute(select_query)

pronoun_rows = cursor.fetchall()

# %% [markdown]
# ## Raw Data

# %%
# let's find out how many entries we have
size = len(pronoun_rows)

print(f"There are {size} instances of {pronoun}")
# Out:
# There are 21290 instances of bro

# %%
# Let's look at a row
print(pronoun_rows[0])
# Out:
# ('2025-02-04T17:02:30.996Z', 'at://did:plc:zljlg7cgdfsl7maqvjjpp7i4/app.bsky.feed.post/3lhejwqzwus2d', 'bro named his dog after william f buckley lmfaoo')

# %%
# We want to see some. But let's not blow it up
max_table_rows = int(size * .2)
raw_slice_size = int(max_table_rows * .1)

pd.set_option('display.max_rows', max_table_rows )
pd.set_option('display.max_colwidth', None)

# %%
raw_frame = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)
raw_frame.style\
    .hide(axis="index")\
    .set_caption(f"Showing {raw_slice_size} of {size}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3bbc4">
#   <caption>Showing 425 of 21290</caption>
#   <thead>
#     <tr>
#       <th id="T_3bbc4_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_3bbc4_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_3bbc4_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3bbc4_row0_col0" class="data row0 col0" >2025-02-04T17:02:30.996Z</td>
#       <td id="T_3bbc4_row0_col1" class="data row0 col1" >at://did:plc:zljlg7cgdfsl7maqvjjpp7i4/app.bsky.feed.post/3lhejwqzwus2d</td>
#       <td id="T_3bbc4_row0_col2" class="data row0 col2" >bro named his dog after william f buckley lmfaoo</td>
#     </tr>
#     <tr>
#       <td id="T_3bbc4_row1_col0" class="data row1 col0" >2025-02-04T17:03:02.319Z</td>
# ...

# %% [markdown]
# ## Prettify the data
# Let's find some ways to make the data a little more presentable. Let's get real URLs, a cleaner timestamp, and highlight the word.

# %%
from src.notebook_helpers import make_link
from src.notebook_helpers import prettify_time
from src.notebook_helpers import mark

# %%
highlight = lambda s: f'{mark(s, "(bro+)")}'

# %%
pretty_data = pd.DataFrame(pronoun_rows[0:raw_slice_size], columns=column_titles)

pretty_data = pretty_data.reset_index(drop=True)

pretty_data.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb8d5">
#   <caption>Showing 425 of 21290 instances of bro</caption>
#   <thead>
#     <tr>
#       <th id="T_eb8d5_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_eb8d5_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_eb8d5_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eb8d5_row0_col0" class="data row0 col0" >Feb 04, 2025 05:02PM</td>
#       <td id="T_eb8d5_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:zljlg7cgdfsl7maqvjjpp7i4/post/3lhejwqzwus2d">Post</a></td>
#       <td id="T_eb8d5_row0_col2" class="data row0 col2" ><mark>bro</mark> named his dog after william f buckley lmfaoo</td>
#     </tr>
#     <tr>
#       <td id="T_eb8d5_row1_col0" class="data row1 col0" >Feb 04, 2025 05:03PM</td>
# ...

# %% [markdown]
# ## What about the Pejorative Bro?
#
# Pejorative-Bro is a noun+bro construction used to disparage a person with a special interest.
#
# Common pejorative bros are:
#
# * tech
# * finance
# * gym
# * crypto
# * ai
#
# We'll search for those, or a `[word]-bro`

# %%
bro_mods = ['tech','crypto', 'gym', 'finance', 'douche', 'ai', 'musk', 'art', 'debate']
pejorative_regex = re.compile(f'((?:{"|".join(bro_mods)})(?:\\s|-)?bros?)|\\w+-bros?')
pejorative_rows = [row for row in pronoun_rows if pejorative_regex.search(row[2])]
pejorative_highlight = lambda s: f'{mark(s, f'(((?:{"|".join(bro_mods)})(?:\\s|-)?bros?)|\\w+-bros?)')}'

pejorative_bro_rows = {} #for inspection if needed

for mod in bro_mods:
    mod_regex = re.compile(f"({mod}(?:\\s|-)?bros?)")
    rows = [row for row in pejorative_rows if mod_regex.search(row[2])]
    pejorative_bro_rows[mod] = rows

pejorative_bro_counts = {k:len(v) for k,v in zip(pejorative_bro_rows.keys(), pejorative_bro_rows.values())}
total_pbr = len(pejorative_rows)
pbr_data = {'Modifier': pejorative_bro_counts.keys(), 'Count': pejorative_bro_counts.values()}
pmd = pd.DataFrame(pbr_data)
pmd['Percent'] = (pmd['Count'] / pmd['Count'].sum()) * 100
pmd.style\
    .hide(axis="index")\
    .set_caption(f"Occurences of Pejorative Bro out of {total_pbr} total instances")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c61f">
#   <caption>Occurences of Pejorative Bro out of 1628 total instances</caption>
#   <thead>
#     <tr>
#       <th id="T_0c61f_level0_col0" class="col_heading level0 col0" >Modifier</th>
#       <th id="T_0c61f_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_0c61f_level0_col2" class="col_heading level0 col2" >Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c61f_row0_col0" class="data row0 col0" >tech</td>
#       <td id="T_0c61f_row0_col1" class="data row0 col1" >1326</td>
#       <td id="T_0c61f_row0_col2" class="data row0 col2" >82.719900</td>
#     </tr>
#     <tr>
#       <td id="T_0c61f_row1_col0" class="data row1 col0" >crypto</td>
#       <td id="T_0c61f_row1_col1" class="data row1 col1" >115</td>
#       <td id="T_0c61f_row1_col2" class="data row1 col2" >7.174049</td>
#     </tr>
#     <tr>
#       <td id="T_0c61f_row2_col0" class="data row2 col0" >gym</td>
# ...

# %%
pretty_pej_data = pd.DataFrame(pejorative_rows, columns=column_titles)
pretty_pej_data = pretty_pej_data.reset_index(drop=True)
pretty_pej_data.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=pejorative_highlight, escape='html' )\
    .set_caption(f"Showing {total_pbr} instances of {"|".join(bro_mods)} {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_184cf">
#   <caption>Showing 1628 instances of tech|crypto|gym|finance|douche|ai|musk|art|debate bro</caption>
#   <thead>
#     <tr>
#       <th id="T_184cf_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_184cf_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_184cf_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_184cf_row0_col0" class="data row0 col0" >Feb 04, 2025 05:04PM</td>
#       <td id="T_184cf_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:3gxlsgpcwwppj37l2l3ygrpo/post/3lhejzy7yvc2d">Post</a></td>
# ...

# %% [markdown]
# ## Now let's look at some sentiment

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
rows_with_sentiment = []
column_titles = ['Time', 'URI', 'Post Text', 'Negative', 'Neutral', 'Positive', 'Compound']

neg_count = 0
pos_count = 0
neu_count = 0
for row in pronoun_rows:
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(row[2])
    row_as_list = list(row)
    row_as_list.append(ss['neg'])
    neg_count += ss['neg']
    row_as_list.append(ss['neu'])
    neu_count += ss['neu']
    row_as_list.append(ss['pos'])
    pos_count += ss['pos']
    row_as_list.append(ss['compound'])
    rows_with_sentiment.append(row_as_list)



pretty_sentiment = pd.DataFrame(rows_with_sentiment[0:raw_slice_size], columns=column_titles)

ps = pretty_sentiment.reset_index(drop=True)

ps.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .format(subset=['Post Text'], formatter=highlight, escape='html' )\
    .set_caption(f"Showing {raw_slice_size} of {size} instances of {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b18b1">
#   <caption>Showing 425 of 21290 instances of bro</caption>
#   <thead>
#     <tr>
#       <th id="T_b18b1_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_b18b1_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_b18b1_level0_col2" class="col_heading level0 col2" >Post Text</th>
#       <th id="T_b18b1_level0_col3" class="col_heading level0 col3" >Negative</th>
#       <th id="T_b18b1_level0_col4" class="col_heading level0 col4" >Neutral</th>
#       <th id="T_b18b1_level0_col5" class="col_heading level0 col5" >Positive</th>
#       <th id="T_b18b1_level0_col6" class="col_heading level0 col6" >Compound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b18b1_row0_col0" class="data row0 col0" >Feb 04, 2025 05:02PM</td>
# ...

# %%
mean_neg = neg_count / len(pronoun_rows)
mean_pos = pos_count / len(pronoun_rows)
mean_neu = neu_count / len(pronoun_rows)

print(f"""
Mean Negative Sentiment {mean_neg}
Mean Positive Sentiment {mean_pos}
Mean Neutral Sentiment {mean_neu}
""")
# Out:
# Mean Negative Sentiment 0.10793100046970425
# Mean Positive Sentiment 0.11620070455612957
# Mean Neutral Sentiment 0.7758673555659956

# %% [markdown]
# ## Now some other useful information from context

# %%
from src.notebook_helpers import get_frequency_dict, get_instance_dict
from src.regexes import PROFANITY_REGEX
from src.regexes import AFFIRMATION_REGEX
from src.regexes import NEGATION_REGEX
from src.regexes import EMOJI_REGEX

# %%
negations = get_frequency_dict(pronoun_rows, NEGATION_REGEX)
affirmations = get_frequency_dict(pronoun_rows, AFFIRMATION_REGEX)
profanities = get_frequency_dict(pronoun_rows, PROFANITY_REGEX)
emojis = get_frequency_dict(pronoun_rows, EMOJI_REGEX)

# %%
total_negations = sum( v for k,v in negations.items() )
total_affirmations =  sum( v for k,v in affirmations.items() )
total_profanities = sum( v for k,v in affirmations.items() )
total_emojis = sum(v for k,v in emojis.items() )

# %%
negation_density = get_instance_dict(negations.keys(), pronoun_rows)
total_neg_posts = sum( v for k,v in negation_density.items() )

neg_table = pd.DataFrame(negations.items(), columns=['Negation', 'Total Occurences'])
neg_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
nt = neg_table.reset_index(drop=True)

nt['Posts with One'] = nt['Negation'].map(negation_density)
nt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_negations} negations from {len(pronoun_rows)} posts using {pronoun}")
# Out:
# 0
# <style type="text/css">
# </style>
# <table id="T_df11a">
#   <caption>Showing 1282 negations from 21290 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_df11a_level0_col0" class="col_heading level0 col0" >Negation</th>
#       <th id="T_df11a_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_df11a_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df11a_row0_col0" class="data row0 col0" >no</td>
#       <td id="T_df11a_row0_col1" class="data row0 col1" >1069</td>
#       <td id="T_df11a_row0_col2" class="data row0 col2" >982</td>
#     </tr>
#     <tr>
#       <td id="T_df11a_row1_col0" class="data row1 col0" >nah</td>
#       <td id="T_df11a_row1_col1" class="data row1 col1" >132</td>
#       <td id="T_df11a_row1_col2" class="data row1 col2" >130</td>
#     </tr>
#     <tr>
#       <td id="T_df11a_row2_col0" class="data row2 col0" >nope</td>
# ...

# %%
negation_words = list(negation_density.keys())
negation_pattern = re.compile(f'\\b({'|'.join(negation_words)})\\b')
rows_with_negations = list(filter(lambda x: negation_pattern.search(x[2]), pronoun_rows))

rwn = rows_with_negations if len(rows_with_negations) > raw_slice_size else rows_with_negations[0:raw_slice_size]
nd = pd.DataFrame(rwn, columns=column_titles)

nd = nd.reset_index(drop=True)

nd.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .set_caption(f"Showing  {len(rows_with_negations)} instances of negations with {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ed36">
#   <caption>Showing  835 instances of negations with bro</caption>
#   <thead>
#     <tr>
#       <th id="T_1ed36_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_1ed36_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_1ed36_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ed36_row0_col0" class="data row0 col0" >Feb 04, 2025 05:06PM</td>
#       <td id="T_1ed36_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:a55ia2ojiv2cnshifmrc7wr6/post/3lhek5xfw732o">Post</a></td>
# ...

# %%
aff_density = get_instance_dict(affirmations.keys(), pronoun_rows)
total_aff_posts = sum( v for k,v in aff_density.items() )

aff_table = pd.DataFrame(affirmations.items(), columns=['Affirmation', 'Total Occurences'])
aff_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

at = aff_table.reset_index(drop=True)
at['Posts with One'] = at['Affirmation'].map(aff_density)

at.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_affirmations} affirmations from {total_aff_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ada55">
#   <caption>Showing 800 affirmations from 773 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_ada55_level0_col0" class="col_heading level0 col0" >Affirmation</th>
#       <th id="T_ada55_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_ada55_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ada55_row0_col0" class="data row0 col0" >yeah</td>
#       <td id="T_ada55_row0_col1" class="data row0 col1" >404</td>
#       <td id="T_ada55_row0_col2" class="data row0 col2" >393</td>
#     </tr>
#     <tr>
#       <td id="T_ada55_row1_col0" class="data row1 col0" >yes</td>
#       <td id="T_ada55_row1_col1" class="data row1 col1" >178</td>
#       <td id="T_ada55_row1_col2" class="data row1 col2" >175</td>
#     </tr>
#     <tr>
#       <td id="T_ada55_row2_col0" class="data row2 col0" >ya</td>
# ...

# %%
affirmation_words = list(aff_density.keys())
affirmation_pattern = re.compile(f'\\b({'|'.join(affirmation_words)})\\b')
rows_with_affs = list(filter(lambda x: affirmation_pattern.search(x[2]), pronoun_rows))

rwa = rows_with_affs if len(rows_with_affs) > raw_slice_size else rows_with_affs[0:raw_slice_size]
rwad = pd.DataFrame(rwa, columns=column_titles)

rwad = rwad.reset_index(drop=True)

rwad.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .set_caption(f"Showing  {len(rows_with_affs)} instances of affirmations with {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6585d">
#   <caption>Showing  477 instances of affirmations with bro</caption>
#   <thead>
#     <tr>
#       <th id="T_6585d_level0_col0" class="col_heading level0 col0" >Time</th>
#       <th id="T_6585d_level0_col1" class="col_heading level0 col1" >URI</th>
#       <th id="T_6585d_level0_col2" class="col_heading level0 col2" >Post Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6585d_row0_col0" class="data row0 col0" >Feb 04, 2025 05:26PM</td>
#       <td id="T_6585d_row0_col1" class="data row0 col1" ><a href="https://bsky.app/profile/did:plc:qyfq2uu5tiz4nckz46lmiezd/post/3lhelb5hs6k2t">Post</a></td>
#       <td id="T_6585d_row0_col2" class="data row0 col2" >my dad: bro you look pale af today
# me: yeah it’s day 3 of heavy flow and i think im gonna pass out
# him: oh … oh well … dang</td>
#     </tr>
#     <tr>
#       <td id="T_6585d_row1_col0" class="data row1 col0" >Feb 04, 2025 05:45PM</td>
# ...

# %%
prof_density = get_instance_dict(profanities.keys(), pronoun_rows)
total_prof_posts = sum( v for k,v in prof_density.items() )

prof_table = pd.DataFrame(profanities.items(), columns=['Profanity', 'Total Occurences'])
prof_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)

pt = prof_table.reset_index(drop=True)
pt['Posts with One'] = pt['Profanity'].map(prof_density)

pt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_profanities} profanities from {total_prof_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d33b4">
#   <caption>Showing 800 profanities from 12441 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_d33b4_level0_col0" class="col_heading level0 col0" >Profanity</th>
#       <th id="T_d33b4_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_d33b4_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d33b4_row0_col0" class="data row0 col0" >ass</td>
#       <td id="T_d33b4_row0_col1" class="data row0 col1" >1200</td>
#       <td id="T_d33b4_row0_col2" class="data row0 col2" >410</td>
#     </tr>
#     <tr>
#       <td id="T_d33b4_row1_col0" class="data row1 col0" >fucking</td>
#       <td id="T_d33b4_row1_col1" class="data row1 col1" >955</td>
#       <td id="T_d33b4_row1_col2" class="data row1 col2" >876</td>
#     </tr>
#     <tr>
#       <td id="T_d33b4_row2_col0" class="data row2 col0" >shit</td>
# ...

# %%
prof_words = list(prof_density.keys())
print(prof_words)
prof_pattern = re.compile(f'\\b({'|'.join(prof_words)})\\b')
rows_with_profs = list(filter(lambda x: prof_pattern.search(x[2]), pronoun_rows))

rwp = rows_with_profs if len(rows_with_profs) > raw_slice_size else rows_with_profs[0:raw_slice_size]
rwpd = pd.DataFrame(rwa, columns=column_titles)

rwpd = rwpd.reset_index(drop=True)

rwpd.style\
    .hide(axis="index")\
    .format(subset=['Time'], formatter=prettify_time)\
    .format(subset=['URI'], formatter= make_link , escape='html')\
    .set_caption(f"Showing  {len(rows_with_profs)} instances of profanities with {pronoun}")
# Out:
# ['dog', 'f', 't', 'take', 'bull', 'wtf', 'fuck', 'shit', 'big', 'then', 'gay', 'fucking', 'sick', 'cock', 'got', 'asshole', 'hairy', 'man', 'ass', 'hard', 'damn', 'dumb', 'dick', 'fucked', 'daily', 'god', 'cut', 'go', 'n', 'shitheads', 'lmfao', 'fuckin', 'stfu', 'shitload', 'chicken', 'mother', 'bat', 'horse', 'huge', 'shitlib', 'shitcoin', 'butt', 'shitpost', 'fuckers', 'fist', 'shithead', 'omfg', 'fucken', 'shits', 'fat', 'dip', 'shitty', 'cocksuckers', 'bowl', 'freak', 'fuckskvjsjjcs', 'cocktails', 'en', 'fuckload', 'massive', 'fuckkk', 'fucks', 'mo', 'soft', 'shitshow', 'cunt', 'fuckign', 'dickwads', 'cocks', 'poppy', 'fuckkkk', 'dickhead', 'damnnnn', 'dicks', 'shitttttt', 'fucker', 'tongue', 'shithole', 'fuckkkkkkk', 'fucktrump', 'cockroaches', 'aussie', 'shitting', 'damnit', 'latino', 'teen', 'cockring', 'damnation', 'fuckos', 'cocky', 'cocked', 'fuckass', 'fuckingggg', 'fuckkkking', 'fuckkkthat', 'fuckthem', 'fuckrowling', 'fuckwits', 'punch', 'shitstain', 'fuckelon', 'ape', '
# ...

# %%
e_density = get_instance_dict(emojis.keys(), pronoun_rows)
total_e_posts = sum( v for k,v in aff_density.items() )

emoji_table = pd.DataFrame(emojis.items(), columns=['Emoji', 'Total Occurences'])
emoji_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)
et = emoji_table.reset_index(drop=True)
et['Posts with One'] = et['Emoji'].map(e_density)

et.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_negations} emojis from {total_e_posts} posts using {pronoun}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_de0b7">
#   <caption>Showing 1282 emojis from 773 posts using bro</caption>
#   <thead>
#     <tr>
#       <th id="T_de0b7_level0_col0" class="col_heading level0 col0" >Emoji</th>
#       <th id="T_de0b7_level0_col1" class="col_heading level0 col1" >Total Occurences</th>
#       <th id="T_de0b7_level0_col2" class="col_heading level0 col2" >Posts with One</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_de0b7_row0_col0" class="data row0 col0" >😭</td>
#       <td id="T_de0b7_row0_col1" class="data row0 col1" >2753</td>
#       <td id="T_de0b7_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_de0b7_row1_col0" class="data row1 col0" >😂</td>
#       <td id="T_de0b7_row1_col1" class="data row1 col1" >715</td>
#       <td id="T_de0b7_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_de0b7_row2_col0" class="data row2 col0" >🤣</td>
# ...

# %% [markdown]
# ## Associated Pronouns

# %%
from nltk.tokenize import word_tokenize
from collections import Counter


associate_pronouns = Counter()
for row in pronoun_rows:
    text = row[2]
    tokens = word_tokenize(text)
    poss = nltk.pos_tag(tokens)
    for pos in poss:
        tok,p = pos
        if p == 'PRP$':
            associate_pronouns.update([tok.lower()])

total_pronouns = sum( v for k,v in associate_pronouns.items() )
p_density = get_instance_dict(associate_pronouns.keys(), pronoun_rows)

pron_table = pd.DataFrame(associate_pronouns.items(), columns=['Pronoun', 'Total Occurences'])
pron_table.sort_values("Total Occurences", axis=0, ascending=False, inplace=True)


pt = pron_table.reset_index(drop=True)
pt['Posts with One'] = pt['Pronoun'].map(p_density)

pt.style\
    .hide(axis="index")\
    .set_caption(f"Showing {total_pronouns} pronouns that were used with {pronoun}")
